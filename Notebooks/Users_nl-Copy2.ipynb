# %% [markdown]
# # Get user info
#
# In this notebook we'll explore some user groups of interest. We will take two approaches.
# 1. Look at user groups around specific channels and look into their histories.
# 2. Look at user groups around certain topics and look into their histories.

# %% [markdown]
# Let's start with importing the required python libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import glob 
import csv 
import re
import datetime as dt
import sys
import os
import config
import scenariofunctions as sf

# %matplotlib inline
csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %% [markdown]
# Set paths to data. Better to set these paths into a separate config file.

# %%
path_nl = config.PATH_NL
path_right = config.PATH_RIGHT
path_left = config.PATH_LEFT

# %% [markdown]
# IMPORTANT NOTE: some data is really messy, especially the comment data. I had a hard time parsing the data correctly. One of the solutions was to use rare characters as separators and quotechars.
# In this case, I mostly used:
#
# - sep='¶'
# - quotechar='þ'
#
# You need to use the python engine when reading csv, because the C engine doesn't accept these kinds of delimiters.

# %% [markdown]
# ## Merge channels and comments so we can select the users of interest

# %%
nl_comments = pd.read_csv(path_nl + 'comments_nl_right.csv',
                        sep='¶',
                        quotechar='þ',
                        engine='python')

# %%
nl_videos = pd.read_csv(path_nl + 'videos_nl_right.csv')

# %%
nl_comment_sphere = pd.merge(nl_comments, nl_videos, on='video_id', how='left')

# %% [markdown]
# So these are the channels in our Dutch right infosphere and the number of comments we found per channel

# %%
to_delete = ['Omroep PowNed', 
             'GeenStijl', 
             'Cafe Weltschmerz', 
             'Voice of Europe', 
             'Matthew & Doris',
             'ThePostOnline TPO',
             'Al Stankard aka HAarlem VEnison']

# %%
nl_comments = nl_comment_sphere[~nl_comment_sphere['video_channel_title'].isin(to_delete)]

# %%
nl_comments.video_channel_title.value_counts()
# Out:
# Rafiek de Bruin                44645
# Forum Democratie               30290
# Paul Nielsen                   19938
# Linkse Moskee                  15463
# Laurens                        15378
# Leukste YouTube fragmenten     15251
# TheLvkrijger                   15140
# LaVieJanRoos                   11060
# Brave New World                10010
# Deweycheatumnhowe               9995
# PolitiekincorrectTV             8083
# AvariceUntied                   7722
# GeertWildersMedia               4738
# Keihard Producties              3621
# PVVpers                         3181
# PVV Media                       3098
# Pim Fortuyn                     2375
# Politiekman                     1207
# K                                993
# Piet Zwarte                      702
# De saneer-meneer                 502
# Batavieren Podcast               490
# PVVep                            467
# De Dagelijkse Standaard DDS      383
# Hollands Post                    364
# Erkenbrand Kanaal                304
# voorpostmedia                    288
# Res cogitans                     209
# Michael van der Galien           146
# Ruben FVD                        125
# LavendelTV                       115
# lnfideI                           84
# Kartel Schaar                     80
# Zwart Front Activisme             79
# SpectrumNLD                       69
# nvuvoorzitter                     63
# De Nederlandse Leeuw              59
# ID Verzet                         48
# Truth Seeker                      28
# Geen AZC in Nederland             22
# NederlandTuigvrij                 22
# pvvdenhaag                        20
# MrVerzet                          20
# Sjors Remmerswaal                 15
# Jongeren FVD                      11
# RVF Landstorm Nederland           11
# Marcel Bas                        10
# PVVFriesland                       5
# Pegida Nederland                   4
# Donar Van Holland                  4
# Faust                              2
# ALBINO                             2
# PVV Groningen                      2
# pvvlimburg                         1
# Name: video_channel_title, dtype: int64

# %%
poi = ['A Stuijt',
        'Adrie Van Dijk',
        'Akka Fietje',
        'Wouter Lensvelt',
        'Willem Sterk',
        'Michael Groenendijk',
        'Milo Overzicht',
        'Mike De Jong',
        'Mike Brink',
        'Nellie Rutten',
        'Paul van Dijck',
        'Peter Jongsma',
        'Piet Hein',
        'Pieter van der Meer',
        'Polder Cannabis Olie team',
        'Politiekman',
        'Raymond Doetjes',
        'Willem Pasterkamp',
        'Wimpiethe3',
        'Willie van het Kerkhof',
        'Vincent Vermeer',
        'Mark Tak',
        'Melvin Jansen',
        'Mark Kamphuis',
        'Tristan van Oosten',
        'Tom dGe-lugs-pa',
        'Tom Van de Pol',
        'Tom Van Gool',
        'Marcel Bruinsma',
        'Maarten van der Poel',
        'Maciano Van der Laan',
        'Tiemen Weistra',
        'TheRdamterror',
        'TheCitroenman1',
        'The flying dutchman',
        'Teun de Heer',
        'Stijn van de Ven',
        'Sjaak v Koten',
        'Sev Vermeer',
        'Tanya De Beer',
        'Tim Pietersen',
        'Alan Holland',
        'Bennie Leip',
        'Bert Prins',
        'Bestheftig',
        'Borisje Boef',
        'Chris Van Bekkum',
        'Coen Bijpost',
        'Cornelis van der Heijden',
        'David Teunissen',
        'David Van der Tweel',
        'De Veelvraat',
        'Dennis Bouma',
        'Dennis Eijs',
        'Donald gekkehenkie',
        'peter van',
        'onbekende telefoon',
        'nick van achthoven',
        'mikedehoogh black flag race photos',
        'kristof verbruggen',
        'jan holdijk',
        'jan Yup',
        'iwan munnikes',
        'hans van de mortel',
        'geroestetumor',
        'geheimschriver',
        'gaatje niksaan',
        'dutchmountainsnake',
        'dutch menneer',
        'donder bliksem',
        'boereriem',
        'appie D',
        'adam willems',
        'Yuri Klaver',
         'zuigdoos',
        'yvonneforsmanatyahoo',
        'vanhetgoor',
        'theflyingdutchboi',
        'r juttemeijer',
        'rutger houtdijk',
        'Dutch Patriot',
        'Dutch Whitey',
        'DutchFurnace',
        'Esias Lubbe',
        'Ewalds Eiland',
        'Joey Kuijs',
        'Faust',
        'Hollandia777',
        'Johan van Oldenbarnevelt',
        'Keescanadees',
        'Geert Kok',
        'Haasenpad',
        'Henk Damster',
        'Henk van der Laak',
        'Henri Zwols',
        'Haat Praat',
        'Gerard Mulder',    
        'Grootmeester Jan',
        'H. v. Heeswijk',
        'B. Hagen',
        '1234Daan4321',
        'Daniella Thoelen', 
        'Diederik',
        'Linda Bostoen', 
        'Christiaan Baron', 
        'Matthijs van Guilder',
        'Johannes Roose',
        'Deon Van der Westhuizen', 
        'Remko Jerphanion', 
        'Roosje Keizer',
        'Dennis Durkop',
        'ivar olsen',
        'Pete de pad',
        'georgio jansen',
        'Joel Peter',
        'Antonie de Vry',
        'Stijn Voorhoeve', 
        'liefhebber179',
        'Walter Taljaard',
        'joe van gogh',
        'Edo Peter', 
        'Ad Lockhorst',
        'kay hoorn',
        'Erik Bottema',
        'Deplorable Data',
        'JESSEverything',
        'Harry Balzak', 
        'Bokkepruiker Records',
        'zonnekat',
        'Peter-john De Jong',
        'marco mac',
        'Joubert x',
        'Natasja van Dijk',
        'Voornaam Achternaam',
        'hermanPla', 
        'M. van der Scheer',
        'gerald polyak',
        'Robbie Retro',
        'Johannes DeMoravia',
        'Wouter Vos',
        'AwoudeX',
        'carolineleiden',
        'A-dutch-Z',
        'piet ikke',
        'kutbleat',
        'David of Yorkshire',
        'Gert Tjildsen',
        'Flying Dutchman',
        'Visko Van Der Merwe',
        'Blobbejaan Blob',
        'TheBergbok',
        'jknochel76',
        'Olleke Bolleke',
        'Nayako Sadashi', 'demarcation'  
        'er zaal',
        'jhon jansen',
        '-____-',
        'Brummie Brink',
        'reindeerkid ',
        'Pagan Cloak',
        'NDY',
        'Karel de Kale',
        'top top',
        'Chris Veenendaal ',
        'MijnheerlijkeBuitenlandse befkut ,',
        'Kevin Zilverberg',
        'Rick Dekker ',
        'Adrie Van Dijk ',
        'miep miep',
        'pronto ',
        'TheUnTrustable0',
        'danny schaap',
        'Mark Mathieu',
        'Raysboss302',
        'Ruud Hooreman',
        'Willie W',
        'Barend Borrelworst',
        'theo breytenbach',
         'coinmaster1000 coinmaster1000'  ]

# %%
len(poi)
# Out:
# 179

# %%
nl_right_comments = nl_comments[nl_comments['author_display_name'].isin(poi)]

# %%
len(nl_right_comments)
# Out:
# 11757

# %%
nl_right_comments.video_channel_title.value_counts()
# Out:
# Rafiek de Bruin                3667
# Forum Democratie               1899
# Leukste YouTube fragmenten     1146
# TheLvkrijger                   1052
# Paul Nielsen                    824
# LaVieJanRoos                    641
# Linkse Moskee                   378
# Laurens                         370
# Politiekman                     343
# Deweycheatumnhowe               300
# Keihard Producties              237
# PVV Media                       172
# PolitiekincorrectTV             101
# PVVpers                          82
# Piet Zwarte                      72
# K                                64
# GeertWildersMedia                59
# Brave New World                  58
# De saneer-meneer                 45
# Res cogitans                     43
# De Dagelijkse Standaard DDS      40
# Batavieren Podcast               36
# Pim Fortuyn                      33
# Hollands Post                    24
# Erkenbrand Kanaal                18
# PVVep                             8
# Ruben FVD                         7
# LavendelTV                        7
# SpectrumNLD                       6
# AvariceUntied                     6
# voorpostmedia                     5
# Michael van der Galien            5
# De Nederlandse Leeuw              5
# Kartel Schaar                     2
# ID Verzet                         1
# NederlandTuigvrij                 1
# Name: video_channel_title, dtype: int64

# %% [markdown]
# ## Our users in the international right infosphere

# %%
poi_unique = nl_right_comments.author_channel_id.unique()

# %%
iter_csv = pd.read_csv(path_right + 'comments_right.csv', 
                        chunksize=1000000, 
                        sep='¶',
                        quotechar='þ',
                        engine='python')
int_right_comments = pd.concat([chunk[chunk['author_channel_id'].isin(poi_unique)] for chunk in iter_csv])

# And see how many comments we found of our users
len(int_right_comments)
# Out:
# 34555

# %%
videos_right = pd.read_csv(path_right + 'videos_right.csv', encoding='latin-1')
# Out:
#            video_id           video_published                channel_id  \
# 0       bSx-WpcSvh0  2018-08-08T19:49:03.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 1       SGKcO-NMLb0  2018-07-21T23:05:12.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 2       mWWjMGYJRGo  2018-07-17T22:36:44.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 3       ssJJAmpv8AY  2018-03-29T02:55:36.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 4       JgmPirHGe9Q  2018-03-28T22:29:46.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 5       oYfCKUh4XSg  2018-03-26T21:47:20.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 6       ahpVnHXzXEg  2018-03-26T20:32:40.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 7       EvqQrK0GiUo  2018-03-21T00:00:32.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 8       C2Q_ujM4wJ8  2018-01-01T23:34:55.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 9       Ozns2xXH3VM  2017-12-22T00:56:40.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 10      O3Qx7O_WYGI  2017-12-21T21:47:38.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 11      F-WgQ7VyN7s  2017-12-20T00:13:28.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 12      XQ12ZddQsYs  2017-12-16T23:38:19.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 13      n4sKfpOhvoc  2017-12-16T19:34:00.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 14      5aaaNgvXJyo  2017-08-12T23:23:18.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 15      FwbDJHILRhM  2017-08-11T23:57:40.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 16      WDlQpTu_h9s  2017-08-03T23:32:15.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 17      ymXwDN_WH10  2017-07-31T14:06:29.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 18      0fnI9osyi5c  2017-07-26T23:00:10.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 19      K7kl3do5oCU  2017-07-26T22:56:06.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 20      gLkAsUtRsYA  2017-07-24T23:12:07.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 21      AZwO9jiIyTE  2017-07-21T09:54:15.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 22      _kRRvlgxg9g  2017-06-01T19:46:54.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 23      pSVLe65t9d8  2017-04-13T09:54:45.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 24      EAVIYV-30-4  2017-04-01T19:30:02.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 25      qLZVkmmBHy4  2017-03-30T09:24:25.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 26      miOJpugl-JY  2017-03-05T23:53:13.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 27      NG68my_zI6Y  2017-02-26T20:12:12.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 28      AuapKYGi710  2017-02-26T17:58:25.000Z  UCJIAT4v6irhZChsrB4hzsPA
# 29      9TmX4zNyKMw  2017-02-26T16:01:02.000Z  UCJIAT4v6irhZChsrB4hzsPA
# ...             ...                       ...                       ...
# 263149  7DjGxAcHCxk  2012-08-22T01:00:10.000Z  UC16j6EppP0K85CzYMduNCqw
# 263150  j4Apdtq5Zwk  2012-08-17T21:06:57.000Z  UC16j6EppP0K85CzYMduNCqw
# 263151  1VIue4lSCP4  2012-08-07T06:55:12.000Z  UC16j6EppP0K85CzYMduNCqw
# 263152  A1Z-tnG9tqM  2012-06-08T17:55:48.000Z  UC16j6EppP0K85CzYMduNCqw
# 263153  aSbMuqenP8g  2012-05-07T20:53:56.000Z  UC16j6EppP0K85CzYMduNCqw
# 263154  RHH5AGx3kew  2012-02-19T17:07:22.000Z  UC16j6EppP0K85CzYMduNCqw
# 263155  M0yTp529pvQ  2012-02-07T00:03:40.000Z  UC16j6EppP0K85CzYMduNCqw
# 263156  oZa_szD8vFY  2011-11-04T04:51:13.000Z  UC16j6EppP0K85CzYMduNCqw
# 263157  xwjyssGqfmU  2011-03-06T18:31:44.000Z  UC16j6EppP0K85CzYMduNCqw
# 263158  jBXhiYCsHu8  2011-02-02T23:58:30.000Z  UC16j6EppP0K85CzYMduNCqw
# 263159  Kh0nzMHd1b4  2010-12-16T22:39:05.000Z  UC16j6EppP0K85CzYMduNCqw
# 263160  aW8okI5UDSY  2010-11-09T01:36:07.000Z  UC16j6EppP0K85CzYMduNCqw
# 263161  1W5GR9aJ4dk  2010-09-28T22:17:26.000Z  UC16j6EppP0K85CzYMduNCqw
# 263162  q05TBb7IFPg  2010-08-26T07:12:12.000Z  UC16j6EppP0K85CzYMduNCqw
# 263163  x6_qTkrv7XQ  2010-08-15T02:32:30.000Z  UC16j6EppP0K85CzYMduNCqw
# 263164  Re3fQrSawog  2010-08-15T02:27:27.000Z  UC16j6EppP0K85CzYMduNCqw
# 263165  HC0auVgvwsM  2010-08-10T07:24:23.000Z  UC16j6EppP0K85CzYMduNCqw
# 263166  Mn2iJMRCwEw  2010-08-07T23:05:44.000Z  UC16j6EppP0K85CzYMduNCqw
# 263167  QfRX2V0zFK4  2010-08-07T21:29:25.000Z  UC16j6EppP0K85CzYMduNCqw
# 263168  TZg23B9QrKg  2010-08-03T22:34:44.000Z  UC16j6EppP0K85CzYMduNCqw
# 263169  5C8ctqr-wAs  2010-02-05T19:11:31.000Z  UC16j6EppP0K85CzYMduNCqw
# 263170  EJdQS3v76Cs  2009-10-13T07:11:03.000Z  UC16j6EppP0K85CzYMduNCqw
# 263171  QyDvHcn4imw  2009-07-30T06:32:20.000Z  UC16j6EppP0K85CzYMduNCqw
# 263172  ubMNBQwvV0I  2008-07-30T18:44:54.000Z  UC16j6EppP0K85CzYMduNCqw
# 263173  EUV_p4U38yU  2008-05-09T00:15:44.000Z  UC16j6EppP0K85CzYMduNCqw
# 263174  ZjkJhAHoEd4  2008-04-17T02:08:38.000Z  UC16j6EppP0K85CzYMduNCqw
# 263175  VS-Oq2YbiNE  2008-04-16T05:30:50.000Z  UC16j6EppP0K85CzYMduNCqw
# 263176  cPo0QxUQ7SA  2007-09-26T21:27:55.000Z  UC16j6EppP0K85CzYMduNCqw
# 263177  16qIZFXa3xk  2007-08-19T20:47:08.000Z  UC16j6EppP0K85CzYMduNCqw
# 263178  kFx9zVXGvnU  2007-06-27T03:19:50.000Z  UC16j6EppP0K85CzYMduNCqw
#
#                                               video_title  \
# 0       Trailer for Interview on HPANWO Radio 9 Aug 20...
# 1       Claire Rae Randall ~ Waking the Monkey! Interv...
# 2                      Channel Update ~ The War on Gender
# 3                       False Allegations Made Against Me
# 4                                 Someone Doesn't Like Me
# 5                           The Jeremy Clarkson Postulate
# 6       The War on Gender ~ Pre Book Launch talk Censored
# 7                                        Tolkien in Leeds
# 8       In Memory of Randy California ~ Hero Died 2 Ja...
# 9                 Cliche Came Out Of Its Cage by CS Lewis
# 10                                      My Lean Yule Woes
# 11                 Mark Collett misquotes Jordan Peterson
# 12      The Lion, The Witch and The Kalergification of...
# 13               Channel Update and Millenniyule Schedule
# 14                     Roman Britain and Multiculturalism
# 15      Alex Jones rant Folk Song Infowars.com Competi...
# 16                         Trans Entitlement? Muh Rights!
# 17      Justine Greening/Tories 'Gender Declaration' P...
# 18      President Trump's Transgender Military Exclusi...
# 19                   Is Lauren Southern a Zionist Stooge?
# 20      Please Support Lauren Southern #Defend Europe ...
# 21      Transsexualism, SJWs, Doctor Who, and Waking T...
# 22      Leeds Salon: Future of Democratic Politics ~  ...
# 23      Josie Appleton: Rise of the Busybody State ~ L...
# 24      The War on Gender, Part 2   Weaponised Constructs
# 25      Anne Marie Waters: Sharia in the UK ~ Leeds 29...
# 26      Atkinson Grimshaw:  Meanwood Valley view of St...
# 27                The War on Gender:  Transgender Toilets
# 28      Claire Rae Randall ~ Cultural Marxist Model of...
# 29      Claire Rae Randall ~ Hundredth Monkey: Cultura...
# ...                                                   ...
# 263149                      How To Approach Girls At Bars
# 263150                 There Are No Ugly Girls In America
# 263151          American Women vs. Eastern European Women
# 263152            My response to Bang Colombia criticisms
# 263153                                     Poosy Paradise
# 263154                            Alpha Male vs Beta Male
# 263155       My response to Don't Bang Denmark criticisms
# 263156             My response to Bang Iceland criticisms
# 263157                               Kindle Demonstration
# 263158  Roosh's Brazil Compendium: Pickup Tips, City G...
# 263159                                    My Name Is Omar
# 263160                             This Is Why You're Fat
# 263161                                 It's The Same Shit
# 263162                     Running Into A One-Night Stand
# 263163                       Doughboy's Super Direct Game
# 263164                           Doughboy Game Discussion
# 263165                 Black Men Get Laid Almost Anywhere
# 263166                  Do You Have To Stand Right There?
# 263167                          Did You Fuck On My Couch?
# 263168                              Arm Crossing Approach
# 263169   BOPE Favela Gun Battle in Morro Dona Marta (Rio)
# 263170                  The Truth About Medellin Colombia
# 263171  Two-Minute Introduction to A Dead Bat In Paraguay
# 263172                                        Roosh Cribs
# 263173                     Extreme Big League Competition
# 263174              Highlights of Buenos Aires, Argentina
# 263175                 How To Be A Master Blogger Like Me
# 263176                                   Floating Islands
# 263177                                       Road To Tena
# 263178                           How A Chef Cuts An Onion
#
#                                         video_description video_channel_title  \
# 0       Programme notes  https://hpanwo-radio.blogspot...       Cosmic Claire
# 1       Claire Rae Randall on The Hundredth Monkey Rad...       Cosmic Claire
# 2       Update on the progress of my forthcoming book ...       Cosmic Claire
# 3       Further to the cancellation of my talk 'The Wa...       Cosmic Claire
# 4       Following the cancellation of my pre-launch ev...       Cosmic Claire
# 5       I mean no disrespect to Jeremy Clarkson by thi...       Cosmic Claire
# 6       I am a transsexual woman who has just been shu...       Cosmic Claire
# 7       This is my presentation for the Headingley Lit...       Cosmic Claire
# 8       In memory of Randy California 20 Feb 1951 -2 J...       Cosmic Claire
# 9       My reading of the poem Cliche Came Out Of Its ...       Cosmic Claire
# 10      This is my video explaining my absence from th...       Cosmic Claire
# 11      Here I point out the error which Mark Collett ...       Cosmic Claire
# 12      Today I saw a theatre production of The Lion, ...       Cosmic Claire
# 13      Replacement video for Millenniyule Hangout\nht...       Cosmic Claire
# 14      This is my response to the debate around the B...       Cosmic Claire
# 15      In the style of Peter Sellers' 'A Hard Day's N...       Cosmic Claire
# 16      This is a reply to a YouTuber who uses the pro...       Cosmic Claire
# 17      I oppose the Government's proposed new 'Gender...       Cosmic Claire
# 18      Why would a transsexual person such as myself ...       Cosmic Claire
# 19      Reply to a troll who tried to deflect my Suppo...       Cosmic Claire
# 20      Please support Lauren Southern and #DefendEuro...       Cosmic Claire
# 21      My interview with Paul Obertelli and David Par...       Cosmic Claire
# 22      My review of the debate held by Leeds Salon on...       Cosmic Claire
# 23      Josie Appleton of the Manifesto Club is guest ...       Cosmic Claire
# 24      The second in my series of interviews with Ann...       Cosmic Claire
# 25      I am most grateful to Anne Marie for granting ...       Cosmic Claire
# 26      This was just a test video I accidentally post...       Cosmic Claire
# 27      I had the pleasure today of chatting with Anni...       Cosmic Claire
# 28      This is the interview with Lana Lokteff which ...       Cosmic Claire
# 29      This is the interview I did with Lana Lokteff ...       Cosmic Claire
# ...                                                   ...                 ...
# 263149  More approach tips: http://www.rooshv.com/7-si...             Roosh V
# 263150  Read the whole drama here: http://www.rooshvfo...             Roosh V
# 263151  I used this list as a basis for comparison: ht...             Roosh V
# 263152  Bang Colombia has been making the rounds in Co...             Roosh V
# 263153  This clip shows the three instances that panel...             Roosh V
# 263154  Read more: \n\nhttp://www.rooshv.com/7-things-...             Roosh V
# 263155  Don't Bang Denmark in Danish media:\n\nhttp://...             Roosh V
# 263156  I'm mostly addressing the Facebook comments fo...             Roosh V
# 263157  Full review here: http://www.rooshv.com/the-am...             Roosh V
# 263158  A comparison of Brazilian women and Icelandic ...             Roosh V
# 263159  I'm the white teddy bear. Black man is the bla...             Roosh V
# 263160  Solving the obesity epidemic, one reenactment ...             Roosh V
# 263161                 Conversation with myself in a bar.             Roosh V
# 263162  Awkward confrontation with an old one-night st...             Roosh V
# 263163         Witnessed this conversation at a bus stop.             Roosh V
# 263164  Conversation with my sister about Doughboy's g...             Roosh V
# 263165  Adapted from a comment that a black man left o...             Roosh V
# 263166                 This conversation really happened.             Roosh V
# 263167  Getting to the truth. This conversation really...             Roosh V
# 263168  Conversation I had with a girl about arm cross...             Roosh V
# 263169         Real or fake? Scene from Tropa de Elite 2?             Roosh V
# 263170  If you liked this video then check out my book...             Roosh V
# 263171  A two-minute overview of my book. For more det...             Roosh V
# 263172                            Tour of Roosh's mansion             Roosh V
# 263173  A 28-year-old shows you how to be top dog amon...             Roosh V
# 263174                                 Sights and sounds.             Roosh V
# 263175  Tips and tricks on how I maintain a super popu...             Roosh V
# 263176                     The Uros people live on reeds.             Roosh V
# 263177                       ItÂ´s just a little bumpy...             Roosh V
# 263178  Footage of a professional chef and restaurant ...             Roosh V
#
#                                                video_tags  video_category_id  \
# 0       ['CS Lewis', 'Out of the Silent Planet', 'Voya...               27.0
# 1       ['Hundredth Monkey', 'Waking the Monkey', 'Cla...               27.0
# 2       ['Transgender', 'War on Gender', 'Waking The M...               27.0
# 3                                                 not set               27.0
# 4       ['Transgender', 'Transsexual', 'War on Gender'...               27.0
# 5       ['Transsexual', 'Transgender', 'Jeremy Clarkso...               27.0
# 6       ['Transgender', 'Transsexual', 'Headingley Lit...               27.0
# 7       ['Tolkien', 'Headingley', 'Shire Oak', 'Skyrac...               27.0
# 8       ['Randy California', 'Spirit', 'Hendrix', 'Psy...               27.0
# 9       ['Cliche Came Out Of Its Cage', 'CS Lewis', 'O...               27.0
# 10      ['Millennial Woes', 'Millenniyule', 'Trans Age...               27.0
# 11      ['Mark Collett', 'Jordan Peterson', 'Theryn Me...               27.0
# 12      ['Narnia', 'CS Lewis', 'The Lion The Witch And...               27.0
# 13                    ['Millennial Woes', 'Millenniyule']               27.0
# 14      ['Roman Britain', 'Multicultural', 'Migrants',...               27.0
# 15      ['Infowars', 'Alex Jones', 'Prison Planet', 'W...               27.0
# 16      ['Trans Rights', 'LGBT', 'Gender Declaration',...               27.0
# 17      ['Gender Declaration', 'Trans', 'Transgender',...               27.0
# 18      ['President Trump', 'Donald Trump', 'Transgend...               27.0
# 19      ['Defend Europe', 'Lauren Southern', 'Libya', ...               27.0
# 20      ['Defend Europe', 'Lauren Southern', 'Libya', ...               27.0
# 21      ['Transsexualism', 'Transsexuals', 'SJW', 'Doc...               27.0
# 22      ['Democracy', 'Leeds Salon', 'Immigration', 'R...               27.0
# 23      ['Josie Appleton', 'Manifesto Club', 'Officiou...               27.0
# 24      ['Gender', 'Transgender', 'Transsexual', 'Gend...               27.0
# 25      ['Anne Marie Waters', 'Sharia', 'UKIP', 'Privi...               27.0
# 26      ['YouTube Editor', 'Atkinson Grimshaw', 'Meanw...               27.0
# 27      ['Gender Identity', 'Transgender', 'Transgende...               27.0
# 28      ['Transgender', 'Transsexual', 'Transgender To...               27.0
# 29      ['Hundredth Monkey', 'Waking The Monkey!', 'Cu...               27.0
# ...                                                   ...                ...
# 263149   ['roosh', 'game', 'pickup', 'approach', 'girls']               22.0
# 263150                                          ['roosh']               22.0
# 263151  ['roosh', 'american women', 'eastern european ...               22.0
# 263152  ['colombia', 'bang colombia', 'roosh', 'medell...               22.0
# 263153  ['roosh', "don't bang denmark", 'denmark', 'po...               19.0
# 263154  ['roosh', 'alpha', 'beta', 'feminism', 'game',...               22.0
# 263155                     ['roosh', 'denmark', 'danish']               22.0
# 263156                               ['roosh', 'iceland']               22.0
# 263157                                ['kindle', 'roosh']               28.0
# 263158   ['brazil', 'women', 'girls', 'iceland', 'roosh']               19.0
# 263159                            ['roosh', 'xtranormal']                1.0
# 263160                                     ['xtranormal']                1.0
# 263161                                     ['xtranormal']                1.0
# 263162                                     ['xtranormal']                1.0
# 263163                                     ['xtranormal']                1.0
# 263164                                     ['xtranormal']                1.0
# 263165                  ['xtranormal', 'swagger', 'game']                1.0
# 263166                                     ['xtranormal']                1.0
# 263167  ['xtranormal', 'sex', 'couch', 'one-night', 's...                1.0
# 263168                                     ['xtranormal']                1.0
# 263169  ['favela', 'rio', 'brazil', 'tropa', 'de', 'el...               19.0
# 263170  ['medellin', 'colombia', 'paisa', 'south', 'am...               19.0
# 263171               ['memoir', 'south america', 'roosh']               22.0
# 263172           ['cribs', 'mtvcribs', 'parody', 'roosh']               22.0
# 263173  ['football', 'soccer', 'baseball', 'basketball...               17.0
# 263174  ['buenos', 'aires', 'argentina', 'travel', 'so...               19.0
# 263175  ['wordpress', 'blogs', 'blog', 'blogging', 'we...               26.0
# 263176                    ['peru', 'floating', 'islands']               19.0
# 263177                ['ecuador', 'tena', 'bus', 'andes']               22.0
# 263178  ['cooking', 'cook', 'chef', 'how', 'to', 'cut'...               26.0
#
#        video_default_language video_duration  video_view_count  \
# 0                     not set        PT2M45S              48.0
# 1                     not set     PT1H58M50S              35.0
# 2                     not set       PT26M26S              38.0
# 3                     not set       PT33M57S             137.0
# 4                     not set        PT4M22S             134.0
# 5                     not set       PT18M47S              96.0
# 6                     not set     PT1H19M18S             125.0
# 7                     not set       PT40M49S              77.0
# 8                     not set       PT12M34S             737.0
# 9                     not set        PT3M56S              51.0
# 10                    not set       PT46M47S             136.0
# 11                    not set        PT7M44S             125.0
# 12                    not set       PT23M29S             119.0
# 13                    not set        PT3M45S             105.0
# 14                    not set       PT36M54S             444.0
# 15                    not set        PT1M44S             173.0
# 16                    not set        PT35M6S             675.0
# 17                    not set       PT51M40S             121.0
# 18                    not set       PT20M57S             148.0
# 19                    not set        PT18M8S            1112.0
# 20                    not set       PT14M18S             174.0
# 21                    not set      PT1H2M35S             163.0
# 22                    not set       PT47M45S             113.0
# 23                    not set     PT1H37M16S             186.0
# 24                    not set       PT48M21S             179.0
# 25                    not set      PT1H7M56S           29563.0
# 26                    not set          PT11S              57.0
# 27                    not set       PT54M26S             376.0
# 28                    not set     PT1H27M42S             286.0
# 29                    not set      PT1H3M43S              86.0
# ...                       ...            ...               ...
# 263149                not set       PT10M57S           78389.0
# 263150                not set        PT5M33S           66740.0
# 263151                not set        PT9M48S          163050.0
# 263152                not set        PT7M10S           20531.0
# 263153                not set          PT21S           46681.0
# 263154                not set        PT3M30S          264389.0
# 263155                not set         PT6M6S           53772.0
# 263156                not set        PT5M30S           34599.0
# 263157                not set        PT1M54S            9649.0
# 263158                not set        PT2M49S           27258.0
# 263159                not set         PT1M6S            7767.0
# 263160                not set        PT3M56S           30173.0
# 263161                not set        PT3M12S            8697.0
# 263162                not set        PT3M24S           10599.0
# 263163                not set          PT27S            8469.0
# 263164                not set          PT42S            5972.0
# 263165                not set        PT1M13S           10483.0
# 263166                not set         PT1M7S           12050.0
# 263167                not set        PT1M13S            6672.0
# 263168                not set        PT1M10S            9512.0
# 263169                not set        PT1M50S           25752.0
# 263170                not set        PT3M44S           75163.0
# 263171                not set        PT2M10S           12820.0
# 263172                not set        PT5M39S           25070.0
# 263173                not set        PT3M59S           11116.0
# 263174                not set         PT1M8S            4227.0
# 263175                not set        PT5M50S            7655.0
# 263176                not set          PT25S            1667.0
# 263177                not set          PT34S            3591.0
# 263178                not set          PT39S           67144.0
#
#         video_comment_count  video_likes_count  video_dislikes_count  \
# 0                       8.0                4.0                   1.0
# 1                       2.0                2.0                   0.0
# 2                       7.0                4.0                   0.0
# 3                      11.0                6.0                   1.0
# 4                       9.0               10.0                   0.0
# 5                       8.0                5.0                   1.0
# 6                       3.0                6.0                   0.0
# 7                      12.0                5.0                   0.0
# 8                      10.0               13.0                   0.0
# 9                       2.0                3.0                   0.0
# 10                     16.0               12.0                   1.0
# 11                      2.0                8.0                   0.0
# 12                      8.0               17.0                   2.0
# 13                      9.0               13.0                   0.0
# 14                     10.0               20.0                   5.0
# 15                      3.0               13.0                   1.0
# 16                     39.0               19.0                   3.0
# 17                     31.0                5.0                   2.0
# 18                      6.0               12.0                   1.0
# 19                     25.0               32.0                  12.0
# 20                      4.0               13.0                   3.0
# 21                      7.0                6.0                   1.0
# 22                     10.0                9.0                   2.0
# 23                      0.0                4.0                   0.0
# 24                      6.0                8.0                   2.0
# 25                    489.0              765.0                  33.0
# 26                      6.0                3.0                   0.0
# 27                     12.0               19.0                   2.0
# 28                      2.0               10.0                   0.0
# 29                      3.0                5.0                   1.0
# ...                     ...                ...                   ...
# 263149                381.0              830.0                 455.0
# 263150                815.0              940.0                 555.0
# 263151               2083.0             1246.0                1142.0
# 263152                181.0              142.0                 106.0
# 263153                 23.0               50.0                   7.0
# 263154               1118.0             1230.0                2218.0
# 263155                544.0              372.0                 378.0
# 263156                283.0              242.0                 217.0
# 263157                 15.0               44.0                  26.0
# 263158                 39.0              106.0                 107.0
# 263159                  5.0               47.0                  13.0
# 263160                 66.0              299.0                  50.0
# 263161                  5.0               33.0                  11.0
# 263162                  5.0               58.0                  17.0
# 263163                  2.0               15.0                   5.0
# 263164                  1.0               13.0                   7.0
# 263165                 23.0               54.0                  24.0
# 263166                  3.0               24.0                  12.0
# 263167                  1.0               36.0                   9.0
# 263168                  7.0               24.0                  10.0
# 263169                 29.0               59.0                  10.0
# 263170                303.0              320.0                 661.0
# 263171                  6.0               36.0                  15.0
# 263172                 41.0              110.0                  56.0
# 263173                  7.0               98.0                  34.0
# 263174                  4.0               21.0                  12.0
# 263175                  9.0               61.0                  20.0
# 263176                  1.0               10.0                   7.0
# 263177                  2.0               13.0                   7.0
# 263178                 43.0               53.0                  70.0
#
#                                           video_topic_ids  \
# 0                                ['/m/02jjt', '/m/02jjt']
# 1                                ['/m/02jjt', '/m/02jjt']
# 2       ['/m/019_rr', '/m/0kt51', '/m/019_rr', '/m/0kt...
# 3                              ['/m/019_rr', '/m/019_rr']
# 4                                                 not set
# 5                                ['/m/02jjt', '/m/02jjt']
# 6       ['/m/019_rr', '/m/0kt51', '/m/019_rr', '/m/0kt...
# 7                                ['/m/098wr', '/m/098wr']
# 8                                ['/m/02jjt', '/m/02jjt']
# 9                                ['/m/02jjt', '/m/02jjt']
# 10                               ['/m/02jjt', '/m/02jjt']
# 11                               ['/m/02jjt', '/m/02jjt']
# 12                               ['/m/02jjt', '/m/02jjt']
# 13                               ['/m/02jjt', '/m/02jjt']
# 14                             ['/m/019_rr', '/m/019_rr']
# 15                               ['/m/04rlf', '/m/04rlf']
# 16                               ['/m/098wr', '/m/098wr']
# 17       ['/m/098wr', '/m/05qt0', '/m/098wr', '/m/05qt0']
# 18       ['/m/098wr', '/m/05qt0', '/m/098wr', '/m/05qt0']
# 19                               ['/m/098wr', '/m/098wr']
# 20                               ['/m/098wr', '/m/098wr']
# 21                               ['/m/02jjt', '/m/02jjt']
# 22                                           ['/m/05qt0']
# 23                               ['/m/098wr', '/m/098wr']
# 24                               ['/m/098wr', '/m/098wr']
# 25       ['/m/098wr', '/m/05qt0', '/m/098wr', '/m/05qt0']
# 26                               ['/m/04rlf', '/m/04rlf']
# 27                               ['/m/098wr', '/m/098wr']
# 28                               ['/m/098wr', '/m/098wr']
# 29                               ['/m/098wr', '/m/098wr']
# ...                                                   ...
# 263149  ['/m/019_rr', '/m/03glg', '/m/019_rr', '/m/03g...
# 263150  ['/m/019_rr', '/m/0kt51', '/m/019_rr', '/m/0kt...
# 263151                         ['/m/019_rr', '/m/019_rr']
# 263152                           ['/m/098wr', '/m/098wr']
# 263153   ['/m/0f2f9', '/m/02jjt', '/m/02jjt', '/m/0f2f9']
# 263154  ['/m/0f2f9', '/m/05qjc', '/m/02jjt', '/m/02jjt...
# 263155  ['/m/019_rr', '/m/0kt51', '/m/019_rr', '/m/0kt...
# 263156                         ['/m/019_rr', '/m/019_rr']
# 263157                           ['/m/04rlf', '/m/04rlf']
# 263158                           ['/m/04rlf', '/m/04rlf']
# 263159   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263160   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263161  ['/m/022dc6', '/m/0bzvm2', '/m/0bzvm2', '/m/02...
# 263162   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263163   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263164   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263165   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263166   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263167   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263168   ['/m/02jjt', '/m/02vxn', '/m/02jjt', '/m/02vxn']
# 263169                         ['/m/019_rr', '/m/019_rr']
# 263170                         ['/m/019_rr', '/m/019_rr']
# 263171                         ['/m/019_rr', '/m/019_rr']
# 263172                           ['/m/04rlf', '/m/04rlf']
# 263173  ['/m/019_rr', '/m/0kt51', '/m/019_rr', '/m/0kt...
# 263174                           ['/m/04rlf', '/m/04rlf']
# 263175  ['/m/019_rr', '/m/07c1v', '/m/019_rr', '/m/07c...
# 263176  ['/m/019_rr', '/m/0kt51', '/m/019_rr', '/m/0kt...
# 263177                         ['/m/019_rr', '/m/019_rr']
# 263178  ['/m/02wbm', '/m/019_rr', '/m/019_rr', '/m/02w...
#
#                                    video_topic_categories
# 0         ['https://en.wikipedia.org/wiki/Entertainment']
# 1         ['https://en.wikipedia.org/wiki/Entertainment']
# 2       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 3       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 4                                                 not set
# 5         ['https://en.wikipedia.org/wiki/Entertainment']
# 6       ['https://en.wikipedia.org/wiki/Health', 'http...
# 7               ['https://en.wikipedia.org/wiki/Society']
# 8         ['https://en.wikipedia.org/wiki/Entertainment']
# 9         ['https://en.wikipedia.org/wiki/Entertainment']
# 10        ['https://en.wikipedia.org/wiki/Entertainment']
# 11        ['https://en.wikipedia.org/wiki/Entertainment']
# 12        ['https://en.wikipedia.org/wiki/Entertainment']
# 13        ['https://en.wikipedia.org/wiki/Entertainment']
# 14      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 15                ['https://en.wikipedia.org/wiki/Music']
# 16              ['https://en.wikipedia.org/wiki/Society']
# 17      ['https://en.wikipedia.org/wiki/Society', 'htt...
# 18      ['https://en.wikipedia.org/wiki/Society', 'htt...
# 19              ['https://en.wikipedia.org/wiki/Society']
# 20              ['https://en.wikipedia.org/wiki/Society']
# 21        ['https://en.wikipedia.org/wiki/Entertainment']
# 22             ['https://en.wikipedia.org/wiki/Politics']
# 23              ['https://en.wikipedia.org/wiki/Society']
# 24              ['https://en.wikipedia.org/wiki/Society']
# 25      ['https://en.wikipedia.org/wiki/Politics', 'ht...
# 26                ['https://en.wikipedia.org/wiki/Music']
# 27              ['https://en.wikipedia.org/wiki/Society']
# 28              ['https://en.wikipedia.org/wiki/Society']
# 29              ['https://en.wikipedia.org/wiki/Society']
# ...                                                   ...
# 263149  ['https://en.wikipedia.org/wiki/Hobby', 'https...
# 263150  ['https://en.wikipedia.org/wiki/Health', 'http...
# 263151  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 263152          ['https://en.wikipedia.org/wiki/Society']
# 263153  ['https://en.wikipedia.org/wiki/Television_pro...
# 263154  ['https://en.wikipedia.org/wiki/Television_pro...
# 263155  ['https://en.wikipedia.org/wiki/Health', 'http...
# 263156  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 263157            ['https://en.wikipedia.org/wiki/Music']
# 263158            ['https://en.wikipedia.org/wiki/Music']
# 263159  ['https://en.wikipedia.org/wiki/Entertainment'...
# 263160  ['https://en.wikipedia.org/wiki/Film', 'https:...
# 263161  ['https://en.wikipedia.org/wiki/Video_game_cul...
# 263162  ['https://en.wikipedia.org/wiki/Entertainment'...
# 263163  ['https://en.wikipedia.org/wiki/Film', 'https:...
# 263164  ['https://en.wikipedia.org/wiki/Film', 'https:...
# 263165  ['https://en.wikipedia.org/wiki/Film', 'https:...
# 263166  ['https://en.wikipedia.org/wiki/Film', 'https:...
# 263167  ['https://en.wikipedia.org/wiki/Entertainment'...
# 263168  ['https://en.wikipedia.org/wiki/Entertainment'...
# 263169  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 263170  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 263171  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 263172            ['https://en.wikipedia.org/wiki/Music']
# 263173  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 263174            ['https://en.wikipedia.org/wiki/Music']
# 263175  ['https://en.wikipedia.org/wiki/Technology', '...
# 263176  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 263177  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...
# 263178  ['https://en.wikipedia.org/wiki/Food', 'https:...
#
# [263179 rows x 16 columns]

# %%
int_right_comments = pd.merge(int_right_comments, videos_right, on='video_id', how='left')

# %%
len(int_right_comments)
# Out:
# 35923

# %%
iter_csv = pd.read_csv(path_left + 'comments_left.csv', 
                        chunksize=1000000, 
                        sep='¶',
                        quotechar='þ',
                        engine='python')
int_left_comments = pd.concat([chunk[chunk['author_channel_id'].isin(poi_unique)] for chunk in iter_csv])

# And see how many comments we found of our users
len(int_left_comments)
# Out:
# 14008

# %%
videos_left = pd.read_csv(path_left + 'videos_left.csv', encoding='latin-1')
len(videos_left)
# Out:
# 400206

# %%
int_left_comments = pd.merge(int_left_comments, videos_left, on='video_id', how='left')

# %%
len(int_left_comments)
# Out:
# 14534

# %%
nl_comments.columns
# Out:
# Index(['video_id', 'comment_id', 'author_display_name', 'author_channel_url',
#        'author_channel_id', 'comment_text', 'comment_like_count',
#        'comment_dislike_count', 'comment_time', 'reply_count',
#        'video_published', 'channel_id', 'video_title', 'video_description',
#        'video_channel_title', 'video_tags', 'video_category_id',
#        'video_default_language', 'video_duration', 'video_view_count',
#        'video_comment_count', 'video_likes_count', 'video_dislikes_count',
#        'video_topic_ids', 'video_topic_categories'],
#       dtype='object')

# %%
comments = nl_right_comments.append([int_left_comments, int_right_comments] ,sort=False)

# %%
len(comments)
# Out:
# 277401

# %%
comments = comments.drop_duplicates()

# %%
len(comments)
# Out:
# 277353

# %%
comments.to_csv(path_right + 'comments.csv')

# %%
comments.author_display_name.nunique()
# Out:
# 59435

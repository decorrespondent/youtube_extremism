# %%
import pandas as pd
import config
import csv
import re
from apiclient.discovery import build
from apiclient.errors import HttpError

# %%
YOUTUBE_API_SERVICE_NAME = config.YOUTUBE_API_SERVICE_NAME
YOUTUBE_API_VERSION = config.YOUTUBE_API_VERSION
DEVELOPER_KEY = config.DEVELOPER_KEY
PATH_TEMP_RIGHT = config.PATH_TEMP_RIGHT

# %%
seeds = pd.read_csv(PATH_TEMP_RIGHT + 'right_seeds.csv')

# %%
seeds.head()
# Out:
#                          Id                  Label  country isseed  seedrank  \
# 0  UC_0dwPeY0vQSJGVfRpFvGUg        Winteroffensief  not set     no       NaN
# 1  UC_8WUrPbi8clO6sWt_FDvuA              Rand Paul       US     no       NaN
# 2  UC_bjx_30CFcJFlcjPtG7VHQ  Impact Theory Studios       US     no       NaN
# 3  UC_FX5j6DnMjsocBYFCYu6rg          LDDpersdienst  not set    yes       8.0
# 4  UC_I-bFxOYtpWLyF_CqlBUAw            Mag�nszf�ra  not set     no       NaN
#
#    subscribercount  videocount  viewcount(100s)  Unnamed: 8  \
# 0             32.0         4.0           1150.0         NaN
# 1           9771.0       254.0          26128.0         NaN
# 2           3760.0        15.0            237.0         NaN
# 3             27.0        63.0            372.0         NaN
# 4            823.0        42.0           2964.0         NaN
#
#                 publishedat  daysactive
# 0  2006-06-02T19:42:03.000Z      4256.0
# 1  2011-07-05T15:52:45.000Z      2397.0
# 2  2010-10-13T22:38:04.000Z      2662.0
# 3  2006-08-07T21:41:31.000Z      4190.0
# 4  2013-03-30T02:56:38.000Z      1764.0

# %%
def get_channels(channel_id):
    '''Queries the youtube API and 
    gets a json in return'''
        
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)
    
    response = youtube.channels().list(
    part = 'snippet,contentDetails,topicDetails,statistics,brandingSettings',
    id = channel_id
    ).execute()
    #print('getting channel info for %s' % (channel_id))
    return response


def get_channel_data(response):
    '''Extracts the needed variables 
    from the returned json'''
    
    for channel in response['items']:
        channel_id = channel['id']
        channel_title = channel['snippet']['title']
        channel_description = channel['snippet']['description']
        try: #many channels do not set a language so we need to catch the exception
            channel_default_language = channel['snippet']['defaultLanguage']
        except:
            channel_default_language = 'not set'
        try:
            channel_country = channel['snippet']['country']
        except:
            channel_country = 'not set'
        channel_viewcount = channel['statistics']['viewCount']
        channel_commentcount = channel['statistics']['commentCount']
        channel_subscribercount = channel['statistics']['subscriberCount']
        channel_videocount = channel['statistics']['videoCount']
        try:
            channel_topic_ids = channel['topicDetails']['topicIds']
        except:
            channel_topic_ids = 'not set'
        try:
            channel_topic_categories = channel['topicDetails']['topicCategories']
        except:
            channel_topic_categories = 'not set'
            
        try:
            channel_branding_keywords = channel['brandingSettings']['channel']['keywords']
        except:
            channel_branding_keywords = 'not set'
        
        return (channel_id,
                channel_title,
                channel_description,
                channel_default_language,
                channel_country,
                channel_viewcount,
                channel_commentcount,
                channel_subscribercount,
                channel_videocount,
                channel_topic_ids,
                channel_topic_categories,
                channel_branding_keywords)

# %%
channel_output = PATH_TEMP_RIGHT + 'channels.csv'
channel_input = seeds
count = -1 # if there is an error, it's easier to find the index position from where to continue

with open(channel_output, "a") as csvFile:
    fieldnames = ['channel_id',
                  'channel_title',
                  'channel_description',
                  'channel_default_language',
                  'channel_country',
                  'channel_viewcount',
                  'channel_commentcount',
                  'channel_subscribercount',
                  'channel_videocount',
                  'channel_topic_ids',
                  'channel_topic_categories',
                  'channel_branding_keywords'                                 
                 ]

    writer = csv.DictWriter(csvFile, fieldnames=fieldnames)
    writer.writeheader()

    for channel in channel_input['Id']:
        try:
            response = get_channels(channel)
            variabelen = get_channel_data(response)
            (channel_id,
            channel_title,
            channel_description,
            channel_default_language,
            channel_country,
            channel_viewcount,
            channel_commentcount,
            channel_subscribercount,
            channel_videocount,
            channel_topic_ids,
            channel_topic_categories,
            channel_branding_keywords) = variabelen
        except:
            continue

        writer.writerow({'channel_id': channel_id, 
                         'channel_title': channel_title, 
                         'channel_description': channel_description, 
                         'channel_default_language': channel_default_language, 
                         'channel_country': channel_country,
                         'channel_viewcount': channel_viewcount,
                         'channel_commentcount': channel_commentcount,
                         'channel_subscribercount': channel_subscribercount,
                         'channel_videocount': channel_videocount,
                         'channel_topic_ids': channel_topic_ids,
                         'channel_topic_categories': channel_topic_categories,
                         'channel_branding_keywords': channel_branding_keywords  
                        })
        count += 1

        print('wrote data for ' + channel_title + ' and index is ' + str(count))
# Out:
# wrote data for Winteroffensief and index is 0
# wrote data for Rand Paul and index is 1
# wrote data for Impact Theory Studios and index is 2
# wrote data for LDDpersdienst and index is 3
# wrote data for Magánszféra and index is 4
# wrote data for BaldTerror and index is 5
# wrote data for Palóc Videotéka and index is 6
# wrote data for Svegot and index is 7
# wrote data for •CRITICAL CONDITION• and index is 8
# wrote data for NPI / Radix and index is 9
# wrote data for În Linie Dreaptă and index is 10
# wrote data for Bat'ko and index is 11
# wrote data for Caleb Maddix and index is 12
# wrote data for Right To Rise PAC and index is 13
# wrote data for NSDAP Clan l Hitler Jugend and index is 14
# wrote data for Gaelic Neoreactionary and index is 15
# wrote data for Esterreicherr and index is 16
# wrote data for rinnenmaker and index is 17
# wrote data for JUGENDproNRW and index is 18
# wrote data for No To Challenge 25 and index is 19
# wrote data for Donald Robertson and index is 20
# wrote data for tihichat and index is 21
# wrote data for Identitäre Hessen and index is 22
# wrote data for Avanti Traficante and index is 23
# wrote data for kanal schnellroda and index is 24
# wrote data for PEGIDA Schweiz and index is 25
# wrote data for Identitäre Bewegung Sachsen-Anhalt and index is 26
# wrote data for Objective Realist and index is 27
# wrote data for Sargon of Akkad and index is 28
# wrote data for agenceinfolibre and index is 29
# wrote data for Thomas Baden-Rice and index is 30
# wrote data for Полтава Свобода and index is 31
# wrote data for John Collins and index is 32
# wrote data for OfficialACLJ and index is 33
# wrote data for Claudio Dalton de Almeida Junior and index is 34
# wrote data for seeprogress and index is 35
# wrote data for Valid Thought and index is 36
# wrote data for DENK TV and index is 37
# wrote data for Babylonian Hebrew and index is 38
# wrote data for Isreality Nederland and index is 39
# wrote data for Lauren Rose and index is 40
# wrote data for Styxhexenhammer666 and index is 41
# wrote data for American Freedom Law Center and index is 42
# wrote data for Political Islam and index is 43
# wrote data for ReasonTV and index is 44
# wrote data for Argent and index is 45
# wrote data for GUD Lyon and index is 46
# wrote data for RAPALJE Celtic Folk Music and index is 47
# wrote data for npdhamburg.de and index is 48
# wrote data for Национално Единство and index is 49
# wrote data for St37One and index is 50
# wrote data for BelleetRebelleParis and index is 51
# wrote data for vlaamsbelangjongeren and index is 52
# wrote data for Caolan Robertson and index is 53
# wrote data for La Falange Barcelona and index is 54
# wrote data for Trinity Channel and index is 55
# wrote data for The Great Order and index is 56
# wrote data for PEGIDA UK and index is 57
# wrote data for PEGIDA Frankfurt Main and index is 58
# wrote data for Tom Boonen and index is 59
# wrote data for Parlamenti közvetítés and index is 60
# wrote data for Palaestra Media and index is 61
# wrote data for Ultra Violet and index is 62
# wrote data for TVLongPlay and index is 63
# wrote data for Michael van der Galien and index is 64
# wrote data for LutheranSatire and index is 65
# wrote data for Hans Verreyt and index is 66
# wrote data for Andywarski and index is 67
# wrote data for CPPI Youtube and index is 68
# wrote data for HVGonline and index is 69
# wrote data for Joshua Blakely and index is 70
# wrote data for Raheem Kassam and index is 71
# wrote data for scars and tears and index is 72
# wrote data for The Alternative Hypothesis and index is 73
# wrote data for Boris Le Lay and index is 74
# wrote data for Voice Of Sandra Solomon and index is 75
# wrote data for Acastus Cor and index is 76
# wrote data for Libertarian Realist and index is 77
# wrote data for One Man's Chorus and index is 78
# wrote data for UKIP MEPs and index is 79
# wrote data for Matt Reis and index is 80
# wrote data for Kiz Kitler and index is 81
# wrote data for Patriotischer Fruehling and index is 82
# wrote data for Alliance for Peace and Freedom (APF) and index is 83
# wrote data for Patriotas .es and index is 84
# wrote data for UnyieldingDefiance and index is 85
# wrote data for bnptv and index is 86
# wrote data for ImagesByDavid and index is 87
# wrote data for DNJ TV and index is 88
# wrote data for Traditionalist Worker Party and index is 89
# wrote data for Project England Rising and index is 90
# wrote data for Prawo i Sprawiedliwość and index is 91
# wrote data for Daywave Radio and index is 92
# wrote data for Pegida Canada and index is 93
# wrote data for r v K Today and index is 94
# wrote data for MrThriveAndSurvive and index is 95
# wrote data for Der Volkslehrer and index is 96
# wrote data for N-VA and index is 97
# wrote data for An Vlaanderen and index is 98
# wrote data for Minding: Freedom and index is 99
# wrote data for Jan Barkmann and index is 100
# wrote data for Vox Koshka and index is 101
# wrote data for Dansk Folkeparti and index is 102
# wrote data for Cy Wakeman and index is 103
# wrote data for abbeyfolk and index is 104
# wrote data for Pieter Omtzigt and index is 105
# wrote data for Social Injustice Warrior and index is 106
# wrote data for NOUS VOULONS VIVRE ! and index is 107
# wrote data for Coach Red Pill and index is 108
# wrote data for Michelle Malkin and index is 109
# wrote data for Smash Cultural Marxism and index is 110
# wrote data for Choda and index is 111
# wrote data for NonDualiteit and index is 112
# wrote data for PVVFriesland and index is 113
# wrote data for Forza Nuova Monza e Brianza and index is 114
# wrote data for Radio FN and index is 115
# wrote data for Réka Kinga Papp and index is 116
# wrote data for Sargon of Akkad Live and index is 117
# wrote data for You enter Germany and index is 118
# wrote data for Internet Aristocrat Archive and index is 119
# wrote data for Dubbidubz and index is 120
# wrote data for Bill Whittle and index is 121
# wrote data for AnxietyBoss and index is 122
# wrote data for Litefoot and index is 123
# wrote data for Tommy Robinson and index is 124
# wrote data for CJ Boling and index is 125
# wrote data for Forza Nuova and index is 126
# wrote data for OhFortunae and index is 127
# wrote data for Dyon Spiler and index is 128
# wrote data for Fratelli d'Italia and index is 129
# wrote data for the.truth.will.live and index is 130
# wrote data for Braving Ruin Live and index is 131
# wrote data for Quilliam International and index is 132
# wrote data for NewEuropeANP and index is 133
# wrote data for Scottish Family Party and index is 134
# wrote data for Janet Bloomfield and index is 135
# wrote data for Mikkel Nielsen and index is 136
# wrote data for hspinter and index is 137
# wrote data for Erntegang and index is 138
# wrote data for Revenge Of The Cis and index is 139
# wrote data for Count Dankula and index is 140
# wrote data for Jordan Crowder and index is 141
# wrote data for Realistenfilm and index is 142
# wrote data for ILegionarii and index is 143
# wrote data for Valkyrie Society and index is 144
# wrote data for Charles Zeiger and index is 145
# wrote data for Prinz Eugen and index is 146
# wrote data for Mike Cernovich and index is 147
# wrote data for steve050 and index is 148
# wrote data for Xurious Music and index is 149
# wrote data for Tom Holland and index is 150
# wrote data for hans van hoeflaken and index is 151
# wrote data for ΧΡΥΣΗ ΑΥΓΗ and index is 152
# wrote data for Fiamma Tricolore and index is 153
# wrote data for npdtv and index is 154
# wrote data for Oesterreichzuerst and index is 155
# wrote data for Irish Identitarian and index is 156
# wrote data for NPD Heidenheim and index is 157
# wrote data for Identity Evropa and index is 158
# wrote data for CounterCurrentsTV and index is 159
# wrote data for English Music and index is 160
# wrote data for Forum Democratie and index is 161
# wrote data for justmadeit2 and index is 162
# wrote data for The Masked Arab and index is 163
# wrote data for Generazione Identitaria and index is 164
# wrote data for Freak and Freaks and index is 165
# wrote data for Andrzej Duda and index is 166
# wrote data for Tara McCarthy and index is 167
# wrote data for NPD Niederbayern and index is 168
# wrote data for WhiteRadio and index is 169
# wrote data for not shadowbanned yet and index is 170
# wrote data for CDA and index is 171
# wrote data for Identitás Generáció and index is 172
# wrote data for Brest Info and index is 173
# wrote data for Vlad Tepesblog and index is 174
# wrote data for SakSaret and index is 175
# wrote data for Australian Defence League and index is 176
# wrote data for The Daily Wire and index is 177
# wrote data for Neder1and and index is 178
# wrote data for ThegnOfNorthumbria and index is 179
# wrote data for Baked Alaska and index is 180
# wrote data for NPDThueringenTV and index is 181
# wrote data for Sean O'Rourke and index is 182
# wrote data for Golden Dawn Dubs & Subs and index is 183
# wrote data for New Paradigm and index is 184
# wrote data for AltCapRight and index is 185
# wrote data for tihookeanist and index is 186
# wrote data for NPD Ingolstadt and index is 187
# wrote data for HALLVARD and index is 188
# wrote data for Siim Land and index is 189
# wrote data for RagingPapist and index is 190
# wrote data for Młodzież Wszechpolska Wrocław and index is 191
# wrote data for gaelgeseomra and index is 192
# wrote data for C4Liberty and index is 193
# wrote data for Blazing Catfur and index is 194
# wrote data for Identitarian Future and index is 195
# wrote data for TVRENNES35 and index is 196
# wrote data for Cannes Identitaire and index is 197
# wrote data for Binnenhofvlog and index is 198
# wrote data for Electre and index is 199
# wrote data for Martin Sellner Streams and index is 200
# wrote data for TradeIdee and index is 201
# wrote data for Danskernes Parti and index is 202
# wrote data for The Songman and index is 203
# wrote data for GenerationIDLyon and index is 204
# wrote data for soundmigration and index is 205
# wrote data for dcexaminer and index is 206
# wrote data for LBC and index is 207
# wrote data for Annika O'Brien and index is 208
# wrote data for Falange Española de las JONS and index is 209
# wrote data for A. Kalash and index is 210
# wrote data for Murdoch Murdoch 2 The Reichkening and index is 211
# wrote data for Vlaamseleeuw2010 and index is 212
# wrote data for World of Ultras and index is 213
# wrote data for This is Europa and index is 214
# wrote data for BlitheringGenius and index is 215
# wrote data for nationalistvideo and index is 216
# wrote data for Canadian Nationalist and index is 217
# wrote data for giovanni totzi and index is 218
# wrote data for HSPovci and index is 219
# wrote data for LP - Libertarische Partij and index is 220
# wrote data for Fritz Imperial and index is 221
# wrote data for Panzer Skad and index is 222
# wrote data for BoeingSkunkWorks and index is 223
# wrote data for angelo dell'amico and index is 224
# wrote data for Dancing Dove and index is 225
# wrote data for Social 3state and index is 226
# wrote data for ВО Свобода Одеса and index is 227
# wrote data for si borg and index is 228
# wrote data for fuerBayern and index is 229
# wrote data for Sverige98AD and index is 230
# wrote data for NPDWochenbrief and index is 231
# wrote data for holly hazeltree and index is 232
# wrote data for suvarenee and index is 233
# wrote data for Roaming Media and index is 234
# wrote data for Cultured-Thug and index is 235
# wrote data for Petersen for President 2016 and index is 236
# wrote data for Nordisk alternativhöger and index is 237
# wrote data for kyle birney mc and index is 238
# wrote data for The European Guardian and index is 239
# wrote data for Stefan Molyneux and index is 240
# wrote data for DN TV and index is 241
# wrote data for GroundZeroMosque1 and index is 242
# wrote data for Generace Identity and index is 243
# wrote data for Little Revolution and index is 244
# wrote data for Calling Muslims and index is 245
# wrote data for Oliver Cox and index is 246
# wrote data for NPD Pirmasens and index is 247
# wrote data for LibertarianParty and index is 248
# wrote data for Massimo Pigliucci and index is 249
# wrote data for Kirsten Lauryn and index is 250
# wrote data for Digital Design Dublin and index is 251
# wrote data for Fatmir Alispahic and index is 252
# wrote data for PVVpers and index is 253
# wrote data for CT Rants and index is 254
# wrote data for Goorky and index is 255
# wrote data for theodiskfolk and index is 256
# wrote data for Soldiers of Odin Stockholm and index is 257
# wrote data for UncookedVanilla and index is 258
# wrote data for poker592585 and index is 259
# wrote data for AaronClarey and index is 260
# wrote data for Semiogogue and index is 261
# wrote data for HolodomorInfo.com and index is 262
# wrote data for NPD Paderborn-Höxter and index is 263
# wrote data for Identitäre Bewegung Bayern and index is 264
# wrote data for NPDinDeutschland and index is 265
# wrote data for Lancelot Camelot and index is 266
# wrote data for KM Studio and index is 267
# wrote data for Oltre la Linea and index is 268
# wrote data for Tandem Tricycle and index is 269
# wrote data for TheMorricone and index is 270
# wrote data for Carpediem8110101 and index is 271
# wrote data for strawberrypianist and index is 272
# wrote data for Nordiska motståndsrörelsen and index is 273
# wrote data for spadibur and index is 274
# wrote data for On The Offensive and index is 275
# wrote data for Dr. Steve Turley and index is 276
# wrote data for Dissent Report and index is 277
# wrote data for rorogrincheux and index is 278
# wrote data for LoseTheExtraWeight and index is 279
# wrote data for xagrnet and index is 280
# wrote data for M M and index is 281
# wrote data for Joey Koningsbruggen and index is 282
# wrote data for BloodclawGoesWild and index is 283
# wrote data for Maddox Nabokov and index is 284
# wrote data for Mark Collett and index is 285
# wrote data for Values & Capitalism and index is 286
# wrote data for The Nation and index is 287
# wrote data for Cengiz İnal and index is 288
# wrote data for The Inconvenient Truth and index is 289
# wrote data for The Distributist and index is 290
# wrote data for The Hateful Gaels and index is 291
# wrote data for GruevskiNikola and index is 292
# wrote data for Jenny NZ and index is 293
# wrote data for Matteo Salvini and index is 294
# wrote data for Identitaere Berlin-Brandenburg and index is 295
# wrote data for Mark Steyn and index is 296
# wrote data for Schild & Vrienden and index is 297
# wrote data for Arya Sattya and index is 298
# wrote data for Rennes TV and index is 299
# wrote data for Kartel Schaar and index is 300
# wrote data for Vlaams Belang and index is 301
# wrote data for Matthew Drake and index is 302
# wrote data for Europa Terra Nostra and index is 303
# wrote data for Amy Hanton and index is 304
# wrote data for Partidul Romania Unita Oficial and index is 305
# wrote data for CS Lewis and index is 306
# wrote data for NPD Kreisverband Duisburg and index is 307
# wrote data for ID Verzet and index is 308
# wrote data for Bert Deckers and index is 309
# wrote data for NPDWunsiedel and index is 310
# wrote data for Problematic Bob and index is 311
# wrote data for Timcast and index is 312
# wrote data for darksideofkek and index is 313
# wrote data for Kobiety dla Narodu and index is 314
# wrote data for Organisation Citadelle and index is 315
# wrote data for Richard C Brown and index is 316
# wrote data for slejm - a torkon ragadt politika and index is 317
# wrote data for Alfred Alfer and index is 318
# wrote data for EuropeanUnity565 and index is 319
# wrote data for HighFlyingDutchman and index is 320
# wrote data for mike wilson and index is 321
# wrote data for M. Zirkus and index is 322
# wrote data for Dégauchisez-vous ! and index is 323
# wrote data for Боян Расате and index is 324
# wrote data for WeAreThinking and index is 325
# wrote data for Vamos Falar and index is 326
# wrote data for WhiteDate NET and index is 327
# wrote data for Ryan Faulk and index is 328
# wrote data for Scandza Forum and index is 329
# wrote data for Brittany Pettibone and index is 330
# wrote data for White Student Transmission and index is 331
# wrote data for boilingpoint and index is 332
# wrote data for DeZwarteRat and index is 333
# wrote data for tolvajkergetok and index is 334
# wrote data for Rassemblement National and index is 335
# wrote data for Zwart Front Activisme and index is 336
# wrote data for DCCI Ministries and index is 337
# wrote data for Gestr and index is 338
# wrote data for atlantis49x and index is 339
# wrote data for Србска Акција and index is 340
# wrote data for Right On and index is 341
# wrote data for DANNY LOUGHLIN and index is 342
# wrote data for NPD Sachsen Anhalt and index is 343
# wrote data for Identitäre Bewegung Berlin and index is 344
# wrote data for Jordi Schevens and index is 345
# wrote data for charles martel -PACK and index is 346
# wrote data for The Rovertime Podcast and index is 347
# wrote data for The Swan of Tuonela and index is 348
# wrote data for Entsatzheerfuehrer and index is 349
# wrote data for Stanata Radulov and index is 350
# wrote data for Thomas Sheridan and index is 351
# wrote data for Donar Van Holland and index is 352
# wrote data for Lutz Bachmann and index is 353
# wrote data for Domuitio Germaniae and index is 354
# wrote data for Mundane Chats and index is 355
# wrote data for Thug Nificent and index is 356
# wrote data for ĽS Naše Slovensko v NR SR and index is 357
# wrote data for Avatar of Hyperborea and index is 358
# wrote data for novopress and index is 359
# wrote data for Virginia Vota and index is 360
# wrote data for Caolan Robertson and index is 361
# wrote data for Make-A-Wish Australia and index is 362
# wrote data for Red Ice TV and index is 363
# wrote data for IRISHINFIDEL and index is 364
# wrote data for Alt-Right Tankie- Eurasianist and index is 365
# wrote data for Mister Metokur and index is 366
# wrote data for Sabatina James and index is 367
# wrote data for cpac and index is 368
# wrote data for Life in the Dog House and index is 369
# wrote data for Alt Right Media and index is 370
# wrote data for NPD Pankow and index is 371
# wrote data for Marcel Bas and index is 372
# wrote data for NPD Kreisverband Eichsfeld and index is 373
# wrote data for Patricio Carrasco and index is 374
# wrote data for Batavieren Podcast and index is 375
# wrote data for Virtue of the West w/ Tara McCarthy and index is 376
# wrote data for DS-TV and index is 377
# wrote data for ijzerwakevzw and index is 378
# wrote data for Tim Pool and index is 379
# wrote data for Ontologistics and index is 380
# wrote data for Esoteric Truths and index is 381
# wrote data for DDrummingCoolDude and index is 382
# wrote data for BMPO1893 and index is 383
# wrote data for FarFromEquilibrium and index is 384
# wrote data for ARMIreland and index is 385
# wrote data for CAVALIERKNIGHT33 and index is 386
# wrote data for crull and index is 387
# wrote data for Didymus Sumydid and index is 388
# wrote data for Identitäre Bewegung Deutschland and index is 389
# wrote data for 1nemind and index is 390
# wrote data for Porta Germanica and index is 391
# wrote data for Narodowa Rewolucja and index is 392
# wrote data for Nya Tider and index is 393
# wrote data for Rad Russ and index is 394
# wrote data for THE MERKINS and index is 395
# wrote data for COMPACTTV and index is 396
# wrote data for TheSARGON87 III and index is 397
# wrote data for Sarah and index is 398
# wrote data for Rebel Media and index is 399
# wrote data for Blaue Narzisse and index is 400
# wrote data for orlared and index is 401
# wrote data for ShieldWife and index is 402
# wrote data for Thrillseeker666 and index is 403
# wrote data for FreedomWorks and index is 404
# wrote data for Leiptr and index is 405
# wrote data for Luukkkee and index is 406
# wrote data for Dar0s and index is 407
# wrote data for DJ BSE and index is 408
# wrote data for Jupitarian Vibe and index is 409
# wrote data for Le Média pour Tous and index is 410
# wrote data for Corsica Patria Nostra and index is 411
# wrote data for simal72 and index is 412
# wrote data for Chris Voss and index is 413
# wrote data for Martin Sellner GI and index is 414
# wrote data for Journal Frankfurt and index is 415
# wrote data for zaednomozemepoveke and index is 416
# wrote data for The Greatest Story Never Told TV and index is 417
# wrote data for Jack Buckby and index is 418
# wrote data for Swedish Crusader and index is 419
# wrote data for Reality-Based Leadership and index is 420
# wrote data for Trinity Church Miami and index is 421
# wrote data for Vivaldi Browser and index is 422
# wrote data for Little Enterprises Cali and index is 423
# wrote data for PRIMA LEBEN and index is 424
# wrote data for Malarich and index is 425
# wrote data for Roger Lacey and index is 426
# wrote data for Verbo Tempestas and index is 427
# wrote data for Alt Right and index is 428
# wrote data for Nye Borgerlige TV and index is 429
# wrote data for RadioRapaille and index is 430
# wrote data for Archivio Non Conforme and index is 431
# wrote data for David Cammegh and index is 432
# wrote data for Voice of Europe and index is 433
# wrote data for VlaamsBelangEuropa and index is 434
# wrote data for Forum Anglorum and index is 435
# wrote data for DIEFREIHEITorg and index is 436
# wrote data for Refugee crisis in Europe and index is 437
# wrote data for Caleb Beers and index is 438
# wrote data for Daniel Casmir and index is 439
# wrote data for Samuel Andreyev and index is 440
# wrote data for Prairie Faerie and index is 441
# wrote data for An Fhómhair and index is 442
# wrote data for Български Национален Съюз and index is 443
# wrote data for Chimes of Freedom and index is 444
# wrote data for Conor Jones and index is 445
# wrote data for Manfred Zamzow and index is 446
# wrote data for yahya2006 and index is 447
# wrote data for antimorsayBZH and index is 448
# wrote data for AghonePropaganda and index is 449
# wrote data for Oswald Spengler and index is 450
# wrote data for The Western Front and index is 451
# wrote data for Thomas Wictor and index is 452
# wrote data for LestatDeLioncourt and index is 453
# wrote data for Laut Gedacht and index is 454
# wrote data for ramzpaul and index is 455
# wrote data for Das Leuchtfeuer and index is 456
# wrote data for PSNuoret and index is 457
# wrote data for Gulf City LIVE and index is 458
# wrote data for Expanding Overton and index is 459
# wrote data for Westward Thought and index is 460
# wrote data for Spider58x and index is 461
# wrote data for Glaucio Moraes and index is 462
# wrote data for ProTrier and index is 463
# wrote data for Deutscher Aufklärer and index is 464
# wrote data for Martin Willett and index is 465
# wrote data for David A.R. White and index is 466
# wrote data for Paul Joseph Watson and index is 467
# wrote data for StevenCrowder and index is 468
# wrote data for Don'tConvert2Islam and index is 469
# wrote data for James Allsup and index is 470
# wrote data for PVVep and index is 471
# wrote data for oeuvrefrancaise and index is 472
# wrote data for CroPETROforever and index is 473
# wrote data for Manfred Haimbuchner and index is 474
# wrote data for Der Versucher and index is 475
# wrote data for Vastarintamedia and index is 476
# wrote data for njsvleuven and index is 477
# wrote data for Synthèse nationale and index is 478
# wrote data for Why God? and index is 479
# wrote data for Levente Németh-Cs. and index is 480
# wrote data for Mad Monarchist and index is 481
# wrote data for The Rubin Report and index is 482
# wrote data for Gary Provenzano and index is 483
# wrote data for Jobbik Info and index is 484
# wrote data for Jon Renner and index is 485
# wrote data for Granville Thorndyke and index is 486
# wrote data for НФСБ Благоевград and index is 487
# wrote data for Pale Hominid and index is 488
# wrote data for De saneer-meneer and index is 489
# wrote data for Cosmic Claire and index is 490
# wrote data for Gorgo and index is 491
# wrote data for PovertyCure and index is 492
# wrote data for Content Over Everything and index is 493
# wrote data for The IconoCast and index is 494
# wrote data for Scall Fast and index is 495
# wrote data for Thusnelda34 and index is 496
# wrote data for Fash Bandicoot and index is 497
# wrote data for Morrakiu and index is 498
# wrote data for Forgotten Roots and index is 499
# wrote data for Murdoch Murdoch and index is 500
# wrote data for Skeever ________ and index is 501
# wrote data for spirit of freedom rfb and index is 502
# wrote data for JetztNPDinfo and index is 503
# wrote data for David Cedarwood and index is 504
# wrote data for Bobby Hobert and index is 505
# wrote data for David McMurdo {Druce Gildas} and index is 506
# wrote data for Tony Gerber and index is 507
# wrote data for James McCulloch and index is 508
# wrote data for Sean Last and index is 509
# wrote data for Proud2beNL and index is 510
# wrote data for WhitePowerForEngland and index is 511
# wrote data for STRvideos and index is 512
# wrote data for Roibeárd Mac Seafraidh and index is 513
# wrote data for autrejeunesse and index is 514
# wrote data for Apollonian Germ and index is 515
# wrote data for Nightwave Radio and index is 516
# wrote data for Heel Turn and index is 517
# wrote data for TheBlaze and index is 518
# wrote data for AfD-Fraktion MV and index is 519
# wrote data for Burger Journalist and index is 520
# wrote data for NPDFraktionSachsen and index is 521
# wrote data for Nephanor and index is 522
# wrote data for xryshayghcom and index is 523
# wrote data for Terrace Retro 3 and index is 524
# wrote data for pvvlimburg and index is 525
# wrote data for Gigs in the Streets - music, busking, cover songs and index is 526
# wrote data for Jacquelin Doran and index is 527
# wrote data for NPD KV RO/TS/BGL and index is 528
# wrote data for George Whale and index is 529
# wrote data for Jérôme ROBERT and index is 530
# wrote data for Courageous Conservatives PAC and index is 531
# wrote data for SrpskaElita and index is 532
# wrote data for RANT HUB and index is 533
# wrote data for WhiteRabbitRadioTV and index is 534
# wrote data for No White Guilt and index is 535
# wrote data for Génération ID Lorraine and index is 536
# wrote data for Jordan B Peterson and index is 537
# wrote data for Bastion Social and index is 538
# wrote data for mdtb2008 and index is 539
# wrote data for T Я U Σ Ð I L T O M and index is 540
# wrote data for Fremskrittspartiet and index is 541
# wrote data for sam1987hardcore and index is 542
# wrote data for campusliberty1 and index is 543
# wrote data for Go Chatter and index is 544
# wrote data for DIE FREIHEIT and index is 545
# wrote data for JasinnaRELOADED and index is 546
# wrote data for Anthony Rogers and index is 547
# wrote data for Rich Richards and index is 548
# wrote data for Lauren Southern and index is 549
# wrote data for Paul Weston and index is 550
# wrote data for Rick Wegner and index is 551
# wrote data for johnwitkamp and index is 552
# wrote data for eau19 and index is 553
# wrote data for SarahPalinAK and index is 554
# wrote data for Horatio Cary and index is 555
# wrote data for Millennial Woes and index is 556
# wrote data for Politically incorrect Music and index is 557
# wrote data for Gad Saad and index is 558
# wrote data for DrOakley1689 and index is 559
# wrote data for The Iconoclast and index is 560
# wrote data for Culture de Droite and index is 561
# wrote data for PeterSweden and index is 562
# wrote data for Amorpha Media and index is 563
# wrote data for WallThor and index is 564
# wrote data for NPD Pankow and index is 565
# wrote data for DIETSLAND and index is 566
# wrote data for Future Nations and index is 567
# wrote data for blocidentitaire and index is 568
# wrote data for Norvin Hobbs and index is 569
# wrote data for Faith J Goldy and index is 570
# wrote data for theosophycardiff and index is 571
# wrote data for MarcDoll1977 and index is 572
# wrote data for Leornende Eald Englisc and index is 573
# wrote data for Freak Productions and index is 574
# wrote data for Antipaganda and index is 575
# wrote data for Pure Impact Records and index is 576
# wrote data for English Defence League and index is 577
# wrote data for PolishFans and index is 578
# wrote data for iambulgar and index is 579
# wrote data for Lauren Chen and index is 580
# wrote data for Ecce Lux LiveStreams and index is 581
# wrote data for HIGHLANDKING1 and index is 582
# wrote data for Wider stand and index is 583
# wrote data for Kroc Blanc and index is 584
# wrote data for PEGIDA TV ÖSTERREICH and index is 585
# wrote data for The Sociopath and index is 586
# wrote data for Alerta Judiada Int. 2 and index is 587
# wrote data for Madrid An and index is 588
# wrote data for nsvtv and index is 589
# wrote data for Hogar Social and index is 590
# wrote data for Identity Ireland and index is 591
# wrote data for Alternativ för Sverige and index is 592
# wrote data for Conversations with Bill Kristol and index is 593
# wrote data for Български Национален and index is 594
# wrote data for Erkenbrand Kanaal and index is 595
# wrote data for AfD Wendezeit and index is 596
# wrote data for Insoumis Jules Ngan and index is 597
# wrote data for Elisabeth's philosophy and index is 598
# wrote data for ВО "Свобода" and index is 599
# wrote data for Stoic Elite and index is 600
# wrote data for walk ireland and index is 601
# wrote data for American Renaissance and index is 602
# wrote data for KIDDO KAT and index is 603
# wrote data for Alex´ Kanal and index is 604
# wrote data for Ie theidea and index is 605
# wrote data for NPDFraktionVG and index is 606
# wrote data for Stand For Principle and index is 607
# wrote data for Black Pigeon Speaks and index is 608
# wrote data for misesmedia and index is 609
# wrote data for Philippe VARDON and index is 610
# wrote data for The Motley Discourse and index is 611
# wrote data for Миша Вацић and index is 612
# wrote data for ~ C Y B E R N Δ Z I ~ and index is 613
# wrote data for The Leftovers and index is 614
# wrote data for Orania Beweging and index is 615
# wrote data for The Golden One and index is 616
# wrote data for Bite News and index is 617
# wrote data for Carly Fiorina and index is 618
# wrote data for Generation Identity UK & Ireland and index is 619
# wrote data for RobinHoodUKIP and index is 620
# wrote data for Lars P and index is 621
# wrote data for AmericanCrossroads and index is 622
# wrote data for Dave Martel and index is 623
# wrote data for One America News Network and index is 624
# wrote data for exchagehistory and index is 625
# wrote data for Radosław Olesiński and index is 626
# wrote data for themetalhead667 and index is 627
# wrote data for Theoretical Artist and index is 628
# wrote data for The Red Elephants and index is 629
# wrote data for VBlogIB and index is 630
# wrote data for nsh8corechannel and index is 631
# wrote data for DrzavaBosna and index is 632
# wrote data for David Duke and index is 633
# wrote data for RSBN and index is 634
# wrote data for Steven Hoog and index is 635
# wrote data for Der Dritte Weg and index is 636
# wrote data for Illuminatus Pythagoras and index is 637
# wrote data for galdragildi and index is 638
# wrote data for EuropeanWatchman2 and index is 639
# wrote data for Tobias Steiger and index is 640
# wrote data for eyeofodinband and index is 641
# wrote data for AnglosphereAlIiance and index is 642
# wrote data for programatanasdsm and index is 643
# wrote data for European Reconquista and index is 644
# wrote data for Thinking-Ape and index is 645
# wrote data for Thomas Baden-Riess and index is 646
# wrote data for AIFDtv and index is 647
# wrote data for Jobbikcom and index is 648
# wrote data for Kassendek and index is 649
# wrote data for voteleavemedia and index is 650
# wrote data for Fremskrittspartiets Ungdom and index is 651
# wrote data for Ylle and index is 652
# wrote data for PVV Groningen and index is 653
# wrote data for Frederik Jan Roebersen and index is 654
# wrote data for Jordan B Peterson Clips and index is 655
# wrote data for Herr Anwalt and index is 656
# wrote data for Aarvoll and index is 657
# wrote data for David Vance and index is 658
# wrote data for Force&Independance and index is 659
# wrote data for NPD Westpfalz and index is 660
# wrote data for Tim Kellner and index is 661
# wrote data for Pegida Ireland and index is 662
# wrote data for Identitäre Aktion and index is 663
# wrote data for Boston Antifa and index is 664
# wrote data for Bre Faucheux and index is 665
# wrote data for X E L A S O M A and index is 666
# wrote data for Jean-Francois Gariépy and index is 667
# wrote data for Make Britain Great Again and index is 668
# wrote data for Rebel Canada and index is 669
# wrote data for SkepticalDoctor and index is 670
# wrote data for La Falange and index is 671
# wrote data for Rebel Edge and index is 672
# wrote data for nemzeti1tv and index is 673
# wrote data for My life is a meme and index is 674
# wrote data for VertigoPolitix and index is 675
# wrote data for Génération Nation and index is 676
# wrote data for eyesplice17 and index is 677
# wrote data for Pan-European Movement and index is 678
# wrote data for Hillsdale College Online Courses and index is 679
# wrote data for The Mansonite Menace and index is 680
# wrote data for MISTERWONKA7 and index is 681
# wrote data for BigCatKayla Livestreams and index is 682
# wrote data for Blonde in the Belly of the Beast and index is 683
# wrote data for Lorelei La and index is 684
# wrote data for Aussie Madness and index is 685
# wrote data for LaVieJanRoos and index is 686
# wrote data for Identitet Svea and index is 687
# wrote data for Gavin McInnes and index is 688
# wrote data for The Thinkery and index is 689
# wrote data for Traditional Britain Group and index is 690
# wrote data for Le Rebelle Media and index is 691
# wrote data for Disgruntled Leaf Network and index is 692
# wrote data for Bogoljubskij and index is 693
# wrote data for gman4edl03 and index is 694
# wrote data for Ruch Narodowy and index is 695
# wrote data for AbstractEntityJ and index is 696
# wrote data for senatormikelee and index is 697
# wrote data for Knooppunt Delta and index is 698
# wrote data for AfrikanerWeerstand Beweging Nuus Kanaal and index is 699
# wrote data for Vee Live Stream and index is 700
# wrote data for Wolfsbloed Midgardr and index is 701
# wrote data for securefreedom and index is 702
# wrote data for notregme and index is 703
# wrote data for Steve Franssen and index is 704
# wrote data for Bronson Official and index is 705
# wrote data for Kopf Stein Pflaster and index is 706
# wrote data for plurk85 and index is 707
# wrote data for По программе Дедушки Мороза and index is 708
# wrote data for Ábel Bódi and index is 709
# wrote data for SirOssisOfLiver and index is 710
# wrote data for StadtkewitzTV and index is 711
# wrote data for Paul Lawlor and index is 712
# wrote data for RafaVideoart and index is 713
# wrote data for Mike Licona and index is 714
# wrote data for Kohlenkeller and index is 715
# wrote data for Identitäre Bewegung Würzburg und Umland and index is 716
# wrote data for AfD Kompakt TV and index is 717
# wrote data for Sverigedemokraterna and index is 718
# wrote data for DNInforma and index is 719
# wrote data for Third Position and index is 720
# wrote data for disinformation and index is 721
# wrote data for Tyrant Fashister and index is 722
# wrote data for Analytical Chick and index is 723
# wrote data for Robert Scoble and index is 724
# wrote data for Arthur Powell and index is 725
# wrote data for franz karl and index is 726
# wrote data for 14 Sacred Words and index is 727
# wrote data for ragnarek1945 and index is 728
# wrote data for Constant Kusters and index is 729
# wrote data for Michael Graham and index is 730
# wrote data for Dilara Sak and index is 731
# wrote data for Sebastian Ortiz and index is 732
# wrote data for Mattias Axelsson and index is 733
# wrote data for pvvwebmaster and index is 734
# wrote data for David Yorkshire and index is 735
# wrote data for Madusch and index is 736
# wrote data for Chris Christie and index is 737
# wrote data for Der Schattenmacher and index is 738
# wrote data for 3 Second Rule and index is 739
# wrote data for Franxter and index is 740
# wrote data for Soldiers of Odin Canada and index is 741
# wrote data for Enzymecore and index is 742
# wrote data for Keep the Promise 1 and index is 743
# wrote data for Accounted4U and index is 744
# wrote data for Hagen Grell and index is 745
# wrote data for Reconquista Germanica and index is 746
# wrote data for brtv arzhurig and index is 747
# wrote data for Zmago Jelinčič Plemeniti and index is 748
# wrote data for Sprachenrassist and index is 749
# wrote data for LaughingMan0X and index is 750
# wrote data for Jonathan McLatchie and index is 751
# wrote data for Een En Al and index is 752
# wrote data for Chamber Boys and index is 753
# wrote data for De Dagelijkse Standaard DDS and index is 754
# wrote data for FPÖ TV and index is 755
# wrote data for Rational Nationalist and index is 756
# wrote data for batuli1 and index is 757
# wrote data for Nieuw-Solidaristisch Alternatief and index is 758
# wrote data for CHRIS ARES OFFIZIELL and index is 759
# wrote data for Rudi Prinsloo and index is 760
# wrote data for The Revolutionary Conservative and index is 761
# wrote data for Hel Gower and index is 762
# wrote data for Children of Jewish Holocaust Survivors and index is 763
# wrote data for lhghvideo and index is 764
# wrote data for thefunkyfarmer and index is 765
# wrote data for Andrew Tass and index is 766
# wrote data for International Fellowship of Christians and Jews and index is 767
# wrote data for Artikel 50 and index is 768
# wrote data for activistje and index is 769
# wrote data for renouveaufrancais and index is 770
# wrote data for DetlefF. Artist and index is 771
# wrote data for The Art of Charm and index is 772
# wrote data for inmendham and index is 773
# wrote data for Destructus Maximus and index is 774
# wrote data for Philip G and index is 775
# wrote data for España2000 and index is 776
# wrote data for Disability Federation of Ireland and index is 777
# wrote data for LevinTV and index is 778
# wrote data for hamrthroer Ⓥ and index is 779
# wrote data for Luke Ford Livestreams and index is 780
# wrote data for Agence LDC News and index is 781
# wrote data for Radagis2 and index is 782
# wrote data for Ε.ΛΑ.Μ. Εθνικό Λαϊκό Μέτωπο and index is 783
# wrote data for ToniWienerle and index is 784
# wrote data for Defense Distributed and index is 785
# wrote data for Ministry of Defence and index is 786
# wrote data for ERDÉLYRAP and index is 787
# wrote data for Ariolus Apollon and index is 788
# wrote data for Vangelderden and index is 789
# wrote data for 1302VL and index is 790
# wrote data for AltRight.com and index is 791
# wrote data for Political Channel and index is 792
# wrote data for Christenen voor Israël and index is 793
# wrote data for sundjer bob and index is 794
# wrote data for Marvin Martian and index is 795
# wrote data for nvuvoorzitter and index is 796
# wrote data for Identitäre Bewegung Österreich and index is 797
# wrote data for AfD Fraktion Abgeordnetenhaus Berlin and index is 798
# wrote data for Bigghair and index is 799
# wrote data for ВМРО - ДПМНЕ and index is 800
# wrote data for Candor Inc. and index is 801
# wrote data for crvena rakovica and index is 802
# wrote data for Ladyofthe Labyrinth and index is 803
# wrote data for Silberjunge and index is 804
# wrote data for Carolyn Emerick and index is 805
# wrote data for Irshad Manji and index is 806
# wrote data for Britain First and index is 807
# wrote data for RVF Landstorm Nederland and index is 808
# wrote data for Based Southern Belle and index is 809
# wrote data for UdoKanal and index is 810
# wrote data for L'instant Caucasien and index is 811
# wrote data for voorpostmedia and index is 812
# wrote data for Samuel Calciator and index is 813
# wrote data for Friend of Yahweh and index is 814
# wrote data for FRW Niederlande and index is 815
# wrote data for SVP Schweiz and index is 816
# wrote data for tarpleyy and index is 817
# wrote data for prerodba2008 and index is 818
# wrote data for Antica Tradizione and index is 819
# wrote data for nationinfo and index is 820
# wrote data for markusWielkiPOLAND and index is 821
# wrote data for OrionPrime and index is 822
# wrote data for graaaaaagh and index is 823
# wrote data for IngolstadtFab and index is 824
# wrote data for AfD Baden-Württemberg and index is 825
# wrote data for septem artes and index is 826
# wrote data for MindMastery and index is 827
# wrote data for Theberton and index is 828
# wrote data for grupa 357 official and index is 829
# wrote data for Pegida Bayern and index is 830
# wrote data for Degenerate Survivalist and index is 831
# wrote data for Jules Evans and index is 832
# wrote data for uitgeverijegmont and index is 833
# wrote data for Tagesschlau and index is 834
# wrote data for martelo88 and index is 835
# wrote data for TheMendelin and index is 836
# wrote data for Anti Dem and index is 837
# wrote data for Joe Owens Talking Sense and index is 838
# wrote data for Rossen and index is 839
# wrote data for Mimir's Head and index is 840
# wrote data for aaalll333ccckkksss and index is 841
# wrote data for Nacionālā apvienība VL-TB/LNNK and index is 842
# wrote data for NPD Leipzig and index is 843
# wrote data for JFG Livestreams and index is 844
# wrote data for UltraNacionalPT and index is 845
# wrote data for Aydin Paladin and index is 846
# wrote data for AquilaEvropa1000 and index is 847
# wrote data for SolidarityFront and index is 848
# wrote data for IB Wuppertal and index is 849
# wrote data for schwarzwild666 and index is 850
# wrote data for Iryna Farion and index is 851
# wrote data for Michel Drac and index is 852
# wrote data for OpsporingVerzocht and index is 853
# wrote data for German Ambassador and index is 854
# wrote data for Draugrinn and index is 855
# wrote data for The Goyz in the Hood and index is 856
# wrote data for Creed26Ministries and index is 857
# wrote data for Amadeus Spear and index is 858
# wrote data for NationalSocialistTheory and index is 859
# wrote data for Giorgia Meloni and index is 860
# wrote data for Cmrd Knightmarez and index is 861
# wrote data for Kittensinurface and index is 862
# wrote data for Black Pilled and index is 863
# wrote data for RAC1914 and index is 864
# wrote data for The Irish Megaphone and index is 865
# wrote data for Bosanska Straza and index is 866
# wrote data for WODHANAZSON and index is 867
# wrote data for Verde nel cuore - istituzioni and index is 868
# wrote data for Terrace Retro 2 and index is 869
# wrote data for Pegida Nederland and index is 870
# wrote data for Télé NATION Infos and index is 871
# wrote data for Beatrix von Storch and index is 872
# wrote data for Bosanski Pokret Nacionalnog Ponosa and index is 873
# wrote data for Lega Salvini Premier and index is 874
# wrote data for BloodAndHonour Hexagone and index is 875
# wrote data for Hadraan Le Gaulois and index is 876
# wrote data for OpenMind and index is 877
# wrote data for Alexandre Del Valle and index is 878
# wrote data for Rational Black Pill and index is 879
# wrote data for BayernDieFreiheit and index is 880
# wrote data for Ronan in Siam and index is 881
# wrote data for Franc Studio and index is 882
# wrote data for Nicolaus Fest and index is 883
# wrote data for MOOhammad1 and index is 884
# wrote data for Politiekman and index is 885
# wrote data for #TommyIsFree TOMMY ROBINSON NEWS and index is 886
# wrote data for MumleDK and index is 887
# wrote data for ULTIMA FRONTIERA and index is 888
# wrote data for Gijsbrecht van Neyenrode and index is 889
# wrote data for PNL Moldova and index is 890
# wrote data for Pat Condell and index is 891
# wrote data for Ungsvenskarna and index is 892
# wrote data for Perth Go Players and index is 893
# wrote data for PJ Media and index is 894
# wrote data for Cato's Speech and index is 895
# wrote data for Defend Europe and index is 896
# wrote data for GT Worship and index is 897
# wrote data for jerzy wasner and index is 898
# wrote data for DNJ Barcelona and index is 899
# wrote data for Brass Knuckle Brotherhood and index is 900
# wrote data for IB Hannover and index is 901
# wrote data for GENOVA RAC & Oi! and index is 902
# wrote data for Red Pill France and index is 903
# wrote data for wodansmaiden and index is 904
# wrote data for We The People and index is 905
# wrote data for BlindJusticeOFFICIAL and index is 906
# wrote data for Svenskarnas parti (SvP) and index is 907
# wrote data for DukeOfAvalon and index is 908
# wrote data for jobod92 and index is 909
# wrote data for crosseyedone and index is 910
# wrote data for Nationalism4Life and index is 911
# wrote data for Abendland Deutschland and index is 912
# wrote data for starisloven14 and index is 913
# wrote data for Yaron G and index is 914
# wrote data for Cella Sedui and index is 915
# wrote data for You Kipper and index is 916
# wrote data for Operation Fregin and index is 917
# wrote data for SlavicBosnia and index is 918
# wrote data for Monokulttuuri FM and index is 919
# wrote data for StudentsForWesternCivilisation and index is 920
# wrote data for ReasonableFaithOrg and index is 921
# wrote data for My Outcast State and index is 922
# wrote data for Cinedigm and index is 923
# wrote data for neo-agoge and index is 924
# wrote data for Junge Freiheit Verlag and index is 925
# wrote data for Faust and index is 926
# wrote data for Jack Hampton and index is 927
# wrote data for Salt Mine News Network and index is 928
# wrote data for Parse The Noise and index is 929
# wrote data for Anton Slavik and index is 930
# wrote data for Szent Korona Rádió and index is 931
# wrote data for Vlaams Nationaal Jeugdverbond and index is 932
# wrote data for pvvdenhaag and index is 933
# wrote data for PEsN Deutschland and index is 934
# wrote data for eigentümlich frei and index is 935
# wrote data for EUROPA Tv and index is 936
# wrote data for DukeOfDurham and index is 937
# wrote data for Dn Madrid Videos and index is 938
# wrote data for Understanding the Threat and index is 939
# wrote data for Mar Iusz and index is 940
# wrote data for CasaPound Italia and index is 941
# wrote data for VaynerMedia and index is 942
# wrote data for Falk Hündorf and index is 943
# wrote data for The Patriotic Report and index is 944
# wrote data for reallygraceful and index is 945
# wrote data for Hagens HirnTicker and index is 946
# wrote data for Fred Dietz and index is 947
# wrote data for R3V4LR4D1K4L and index is 948
# wrote data for Acts17Apologetics and index is 949
# wrote data for Right Wing Federation and index is 950
# wrote data for Stan and index is 951
# wrote data for Immortal Ideas and index is 952
# wrote data for La Revanche Blanche and index is 953
# wrote data for London Culture War and index is 954
# wrote data for EMGColonel and index is 955
# wrote data for StateofNation and index is 956
# wrote data for otcetnavmrodpmne and index is 957
# wrote data for Volksdeutscher and index is 958
# wrote data for Greg Johnson and index is 959
# wrote data for IB Schwaben and index is 960
# wrote data for nordfrontmedia and index is 961
# wrote data for jobbikmedia and index is 962
# wrote data for Modemo and index is 963
# wrote data for VAN2012 and index is 964
# wrote data for Vlaamse Volksbeweging and index is 965
# wrote data for Padanik and index is 966
# wrote data for germanicworldsorg and index is 967
# wrote data for Eternal Reich and index is 968
# wrote data for Ulixes Orobar and index is 969
# wrote data for Active Monad and index is 970
# wrote data for Newstalk and index is 971
# wrote data for Génération Identitaire and index is 972
# wrote data for Owen Benjamin and index is 973
# wrote data for Count Richard Von Coudenhove kalergi and index is 974
# wrote data for Sheik and index is 975
# wrote data for Adsav PPB, Le Parti du Peuple Breton and index is 976
# wrote data for Lost Position and index is 977
# wrote data for New Brit Workshop and index is 978
# wrote data for Tom2736 and index is 979
# wrote data for KasparovCom and index is 980
# wrote data for Deutschland Russland and index is 981
# wrote data for Vive L'Europe and index is 982
# wrote data for Rowlan and index is 983
# wrote data for Alex Geussens and index is 984
# wrote data for makedonBULGAR and index is 985
# wrote data for The Plebeian Podcast and index is 986
# wrote data for Lga Lga and index is 987
# wrote data for AlruneRod2811 and index is 988
# wrote data for Młodzież Wszechpolska Tarnów and index is 989
# wrote data for Survive the Jive and index is 990
# wrote data for NeaFrea and index is 991
# wrote data for artanis2alatariel and index is 992
# wrote data for ПРАВИЙ СЕКТОР and index is 993
# wrote data for Ayla Stewart Wife With A Purpose and index is 994
# wrote data for Hunter Avallone Vlogs and index is 995
# wrote data for Frame Game Radio and index is 996
# wrote data for Doel 2020 and index is 997
# wrote data for Acton Institute and index is 998
# wrote data for Morgoth's Review and index is 999
# wrote data for Julie Borowski and index is 1000
# wrote data for Letters to the Exiles and index is 1001
# wrote data for PEGIDA Infidels and index is 1002
# wrote data for HSP - HRVATSKA STRANKA PRAVA and index is 1003
# wrote data for POSEIDON and index is 1004
# wrote data for Edmund Blackadder and index is 1005
# wrote data for Pilleater and index is 1006
# wrote data for Augustus Sol Invictus and index is 1007
# wrote data for Radio Holos fm and index is 1008
# wrote data for RockingMrE and index is 1009
# wrote data for Spero Patria and index is 1010
# wrote data for Pakeha Rabbit and index is 1011
# wrote data for Sebastian Tynkkynen and index is 1012
# wrote data for whiteMedia4 and index is 1013
# wrote data for Pride France officiel and index is 1014
# wrote data for Apostate Prophet and index is 1015
# wrote data for MrVerzet and index is 1016
# wrote data for grupofilipinosalsa and index is 1017
# wrote data for alpha News UK and index is 1018
# wrote data for Dělnická strana sociální spravedlnosti and index is 1019
# wrote data for stiofanwalsh and index is 1020
# wrote data for AKmedia1 and index is 1021
# wrote data for Campaign for Liberty and index is 1022
# wrote data for 123stealthbomber and index is 1023
# wrote data for PragerU and index is 1024
# wrote data for mw katowice and index is 1025
# wrote data for Xpall Odoc and index is 1026

# %%
channels = pd.read_csv(PATH_TEMP_RIGHT + 'channels.csv')

# %%
patreon = re.compile('patreon')

nonnan = channels.loc[channels.channel_description.notnull()]

# %%
filtered = nonnan[nonnan['channel_description'].str.contains(patreon)]

# %%
pd.options.display.max_colwidth = 200

# %%
filtered['patreon'] = filtered['channel_description'].str.extract('patreon\.com\/([a-zA-Z0-9_&]+)')
# Out:
# /home/dim/Environments/youtube_api/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
filtered.patreon
# Out:
# 126                       cjboling
# 141                   countdankula
# 190                       siimland
# 215                   thisiseuropa
# 226              Carol_dancingdove
# 227                   social3state
# 235              roamingmillennial
# 261                    aaronclarey
# 303          illustratedphilosophy
# 349                      angryswan
# 377                   RealityCalls
# 415                 VlogIdentitaer
# 455                    LautGedacht
# 538                jordanbpeterson
# 561                  theiconoclast
# 581              roamingmillennial
# 609                    blackpigeon
# 656                jordanbpeterson
# 669                           mbga
# 684     blondeinthebellyofthebeast
# 855                          gamba
# 991                 survivethejive
# 1005                     poseidon7
# Name: patreon, dtype: object

# %%
columns = ['videoId', 'published', 'title', 'channel_id', 'channel_title']
videos = pd.read_csv(PATH_TEMP_RIGHT + 'videos.csv', names=columns)

# %%
videos.head()
# Out:
#        videoId                 published  \
# 0  Dxg7Jxou3F4  2018-04-14T04:29:42.000Z
# 1  85HbztRoTUE  2016-11-09T21:18:46.000Z
# 2  sYwkXqL8LX0  2016-10-15T07:19:15.000Z
# 3  MNy5h3yC8pI  2016-11-11T06:21:27.000Z
# 4  M589TmXgGD0  2016-07-22T05:29:29.000Z
#
#                                                   title  \
# 0               Alex Jones Lulz 27 (Fuck Trump Edition)
# 1                                  In Hoc Trumpo Vinces
# 2                                  Thou Shalt Not Stump
# 3                         Liberal Tears, a 2016 vintage
# 4  Alex Jones Lulz 24 (Featuring the Fat Brown Buffalo)
#
#                  channel_id channel_title
# 0  UCJpdwEg7vrj_61e0Bfnx02w      Morrakiu
# 1  UCJpdwEg7vrj_61e0Bfnx02w      Morrakiu
# 2  UCJpdwEg7vrj_61e0Bfnx02w      Morrakiu
# 3  UCJpdwEg7vrj_61e0Bfnx02w      Morrakiu
# 4  UCJpdwEg7vrj_61e0Bfnx02w      Morrakiu

# %%
metadata = pd.read_csv(PATH_TEMP_RIGHT + 'metadata.csv')

# %%
metadata.head()
# Out:
#        videoId  \
# 0  Gdztmp80LWk
# 1  nZy4gyBxVfo
# 2  lsh28plGBl8
# 3  rcQAF50rEvM
# 4  HZ346fsMYk8
#
#                                                                                                                                                                                                description  \
# 0                                                                                                                                                                                Why do you hate goodness?
# 1  A parody of 'Only In America' by Brooks & Dunn, written right after "the red line was crossed" in Syria.\nProtected by Fair Use, assholes.\n\nLyrics: \nSun coming up over Aleppo city\nFarouq Briga...
# 2  We're back where we started before the mediaeval festival at Burghausen in order to answer the question as to why so many Germans - and Europeans in general - are self-destructive Leftists. Why di...
# 3                                                                                                      As part of my tour of Bavaria, I'm at Walhalla. What, the hall of fallen heroes? Yes, in a way.....
# 4  I continue with the Hollywood theme and take a look at the connection between the evil lifestyles of the Hollywood elite and the (im)morality they imprint on their films. I claim fair use for the ...
#
#                                                                                                                                          tags  \
# 0             ['they', 'see', 'me', 'trollin', 'federal', 'departments', 'perry', 'romney', 'ron', 'paul', 'education', 'energy', 'commerce']
# 1                                        ['Syria (Country)', 'Bashar Al-Assad', 'Netanyahu', 'Vladimir Putin', 'Barack Obama (US President)']
# 2                       ['Wanghausen', 'apocalypse', 'four horsemen', 'germany', 'bavaria', 'austria', 'mjolnir magazine', 'david yorkshire']
# 3                                                                 ['Walhalla', '#Walhalla', 'Bavaria', 'David Yorkshire', 'Mjolnir Magazine']
# 4  ['Howard Stern', 'Quentin Tarantino', 'Hollywood', 'child rape', 'Black Panther', 'Roman Polanski', 'David Yorkshire', 'Mjolnir Magazine']
#
#    views  likes  dislikes  comments
# 0   3030    123         6        24
# 1   7967    143        12        29
# 2     96     12         0         2
# 3    592     25         0        18
# 4    538     19         0         7

# %%
nonnanmeta = metadata.loc[metadata.description.notnull()]

# %%
filtered_meta = nonnanmeta[nonnanmeta['description'].str.contains('patreon|litecoin|ethereum|paypal|makersupport|monacoin| ripple|hatreon', case=False)]

# %%
len(filtered_meta)
# Out:
# 14168

# %%
lookup = pd.merge(filtered_meta, videos, on='videoId', how='left')

# %%
len(lookup)
# Out:
# 15352

# %%
lookup.to_csv(PATH_TEMP_RIGHT + 'patreon_lookup.csv')

# %%
lookup['patreon'] = lookup['description'].str.extract('patreon\.com\/([a-zA-Z0-9_&]+)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-506ed4e6ed4e> in <module>()
# ----> 1 lookup['patreon'] = lookup['description'].str.extract('patreon\.com\/([a-zA-Z0-9_&]+)').lower()
#
# ~/Environments/youtube_api/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'lower'

# %%
lookup.patreon.str.lower().unique().tolist()
# Out:
# ['schattenmacher',
#  'criticalcondition',
#  nan,
#  'sargon',
#  'user',
#  'zoe',
#  'thesarkeesianeffect',
#  'styxhexenhammer666',
#  'argenttemplar',
#  'rapalje_celtic_folk_music',
#  'palaestramedia',
#  'thewarskishow',
#  'ryandawson',
#  'raheemkassam',
#  'join',
#  'thealternativehypothesis',
#  'cooltapes',
#  'jordanbpeterson',
#  'mrthriveandsurvive',
#  'mrthrivandsurvie',
#  'mrthrvandsurvive',
#  'mrthrivrandsurvive',
#  'mindingfreedom',
#  'sijw',
#  'coachredpill',
#  'billwhittle',
#  'dmjaurini',
#  'cjboling',
#  'janetbloomfield',
#  'werenotsorry',
#  'countdankula',
#  'gentscofflaw',
#  'alexmalenki',
#  'mikecernovich',
#  'themaskedarab',
#  'bakedalaska',
#  'anatofinnstark',
#  'wlop',
#  'lionsheartproductions',
#  'mattipaalanen',
#  'sandara',
#  'siimland',
#  'thisiseuropa',
#  'carol_dancingdove',
#  'social3state',
#  'roamingmillennial',
#  'kirstenlauryn',
#  'aaronclarey',
#  'semiogogue',
#  'ontheoffensive',
#  'bravingruin',
#  'drsteveturley',
#  'distributist',
#  'blacksunphoenix',
#  'illustratedphilosophy',
#  'truthcomics',
#  'timcast',
#  'slejmshow',
#  'emilyyoucis',
#  'brittanypettibone',
#  'swc',
#  'boilingpoint',
#  'tolvajkergetok',
#  'angryswan',
#  'mundanematt',
#  'theculturereport',
#  'jaydyer',
#  'joiarts',
#  'mistermetokur',
#  'realitycalls',
#  'thethirdwave',
#  'psychedelicmilk',
#  'esoterictruths',
#  'vlogidentitaer',
#  'retrorebel',
#  'jackbuckby',
#  'calebbeers',
#  'calebbeershttps',
#  'danielcasmir',
#  'samuelandreyev',
#  'lautgedacht',
#  'ramzpaul',
#  'freepresskek',
#  'gulfcity',
#  'frogrock',
#  'leeschannel',
#  'dontconvert2islam',
#  'jamesallsup',
#  'rubinreport',
#  'bepatron',
#  'theiconoclast',
#  'forgottenroots',
#  'nephanor',
#  'krishatk',
#  'nowhiteguilt',
#  'philosophicat',
#  'jordanbpetersonadditional',
#  'ninapaley',
#  'quillette',
#  'someblackguy',
#  'bababrinkman',
#  'jasinna',
#  'laurensouthern',
#  'gadsaad',
#  'bretweinstein',
#  'petersweden',
#  'cefinbeorn',
#  'leorneendeealdenglisc',
#  'blackpigeon',
#  'millennialwoes',
#  'theleftoversshow',
#  'thegoldenone',
#  'davemartel',
#  'illuminatuspythagoras',
#  'brefaucheux',
#  'thepublicspace',
#  'mbga',
#  'ourcontinent',
#  'willempetzer',
#  'blondeinthebellyofthebeast',
#  'blondeinthebe',
#  'veemonro',
#  'invite',
#  'notregme',
#  'stevenfranssen',
#  'abelbodi',
#  'hagengrell',
#  'philipghezelbash',
#  'lukeford',
#  'mindmastery',
#  'fr_raphael',
#  'aydinpaladin',
#  'drlayman',
#  'gamba',
#  'blackpilled',
#  'evilhillary',
#  'openmind',
#  'alialexander',
#  'youkipper',
#  'monokulttuuri',
#  'reallygraceful',
#  'mattconyt',
#  'hapasupremacy',
#  'wdtl',
#  'feedthebear',
#  'oliverjanich',
#  'survivethejive',
#  'framegames',
#  'morgoth',
#  'julieborowski',
#  'poseidon7',
#  'thorntonparkadventureclub',
#  'rockingphilosophy',
#  'speropatria',
#  'apostateprophet']

# %%
pat
# Out:
# Empty DataFrame
# Columns: [videoId, description, tags, views, likes, dislikes, comments, published, title, channel_id, channel_title, patreon]
# Index: []
